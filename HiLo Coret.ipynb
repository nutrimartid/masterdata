# %%
import time
import pandas as pd
import numpy as np
import math

t = False
s = False


#TOKOPEDIA 2023
tok1 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tok1 = tok1[tok1['Year'].isin([2023]) & tok1['Brand'].isin(['HiLo','Bundle']) & tok1['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['Invoice','Year', 'Month', 'Date', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tok1['Selling Price'] = tok1['Price (Rp.)'] - tok1['Discount Amount (Rp.)']
tok1.drop(columns = ['Price (Rp.)', 'Discount Amount (Rp.)'], inplace = True)
tok1['Store'] = 'Tokopedia'
tok1['Order #'] = tok1['Invoice']
tok1 = tok1[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]

#TOKOPEDIA 2022
tok2 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Runningan Tokopedia Jan 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tok2 = tok2[tok2['Year'].isin([2022]) & tok2['Brand'].isin(['HiLo','Bundle']) & tok2['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['Invoice','Year', 'Month', 'Date', 'Paid January', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tok2['Selling Price'] = tok2['Price (Rp.)'] - tok2['Discount Amount (Rp.)']
tok2.drop(columns = ['Price (Rp.)', 'Discount Amount (Rp.)'], inplace = True)
tok2['Paid March'] = tok2['Paid January']
tok2['Store'] = 'Tokopedia'
tok2['Order #'] = tok2['Invoice']
tok2 = tok2[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]

#TOKOPEDIA
tok = pd.concat([tok1, tok2], ignore_index = True)
del tok1, tok2
print('Tokped Done')

#SHOPEE
sopi = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Shopee By Selcen Jan 2022 - Apr 2023 rev1.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
sopi = sopi[sopi['Brand'].isin(['HiLo','Bundle']) & sopi['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['No. Pesanan','Year', 'Month', 'Waktu Pesanan Dibuat', 'Paid March','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Setelah Diskon', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
sopi['Selling Price'] = sopi['Harga Setelah Diskon'] * 100
sopi['Date'] = sopi['Waktu Pesanan Dibuat'].astype(str).str.slice(8, 10).astype(int)
sopi.drop(columns = ['Harga Setelah Diskon'], inplace = True)
sopi['Store'] = 'Shopee'
sopi['Order #'] = sopi['No. Pesanan']
sopi = sopi[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Shopee Done')

#LAZADA
laz = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Mar 2023\Rev\Running Lazada By Selcen Jan 2022 - Mar 2023.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
laz = laz[laz['Brand'].isin(['HiLo','Bundle']) & laz['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['Order Number', 'True datetime' ,'Year', 'Month', 'Paid March','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Unit Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
laz['Date'] = laz['True datetime'].astype(str).str.slice(8, 10).astype(int)
laz.rename(columns = {'Unit Price' : 'Selling Price'}, inplace = True)
laz['Store'] = 'Lazada'
laz['Order #'] = laz['Order Number']
laz = laz[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Laz Done')

#TIKTOK
tik = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Mar 2023\Rev\Running TikTok Mar 2023.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tik = tik[tik['Brand'].isin(['HiLo','Bundle']) & tik['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['Order #', 'Date' ,'Year', 'Month', 'Paid March','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price List NFI', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tik.rename(columns = {'Price List NFI' : 'Selling Price'}, inplace = True)
tik['Store'] = 'TikTok'
tik = tik[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('TikTok Done')

#BLIBLI NM
blinm = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Blibli By Selcen Jan 22 - Apr 2023.xlsx",sheet_name = 'Runningan Blibli NM',converters = {'Phone' : str, 'Order #' : str})
blinm = blinm[blinm['Brand'].isin(['HiLo','Bundle']) & blinm['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['No. Order', 'Date' ,'Year', 'Month', 'Paid March','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Produk', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
blinm.rename(columns = {'Harga Produk' : 'Selling Price'}, inplace = True)
blinm['Store'] = 'Blibli'
blinm['Order #'] = blinm['No. Order']
blinm = bli[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk', 'Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Blibli Done')

#BLIBLI LMS
blilm = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Blibli By Selcen Jan 22 - Apr 2023.xlsx",sheet_name = 'Runningan Blibli NM',converters = {'Phone' : str, 'Order #' : str})
blilm = blilm[blilm['Brand'].isin(['HiLo','Bundle']) & blilm['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['No. Order', 'Date' ,'Year', 'Month', 'Paid March','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Produk', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
blilm.rename(columns = {'Harga Produk' : 'Selling Price'}, inplace = True)
blilm['Store'] = 'Blibli'
blilm['Order #'] = blilm['No. Order']
blilm = bli[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk', 'Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Blibli Done')

#BUKALAPAK
bl = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Mar 2023\Rev\Runningan Bukalapak By Selcen Jan 2022 - Mar 23.xlsx",sheet_name = 'Runningan Bukalapak',converters = {'Phone' : str, 'Order #' : str})
bl = bl[bl['Brand'].isin(['HiLo','Bundle']) & bli['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['ID Transaksi','Order Date Seller Centre' ,'Year', 'Month', 'Paid March','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Produk', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
bl['Date'] = bl['Order Date Seller Centre'].astype(str).str.slice(8, 10).astype(int)
bl.rename(columns = {'Harga Produk' : 'Selling Price'}, inplace = True)
bl['Store'] = 'Bukalapak'
bl['Order #'] = bl['ID Transaksi']
bl = bl[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('BL Done')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 11
#       7 s = False
#      10 #TOKOPEDIA 2023
# ---> 11 tok1 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
#      12 tok1 = tok1[tok1['Year'].isin([2023]) & tok1['Brand'].isin(['HiLo','Bundle']) & tok1['Real Nama Produk'].str.contains('HiLo', na = False, case = False)][['Invoice','Year', 'Month', 'Date', 'Paid March', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
#      13 tok1['Selling Price'] = tok1['Price (Rp.)'] - tok1['Discount Amount (Rp.)']
#
# ...

# %%
# Out:
#              Order #    Year    Month  Date   Store Paid April    Brand  \
# 0       1.056706e+15  2023.0  January    25  Lazada       Paid       TS
# 1       1.056706e+15  2023.0  January    25  Lazada       Paid       TS
# 2       1.056706e+15  2023.0  January    25  Lazada       Paid       TS
# 3       1.056706e+15  2023.0  January    25  Lazada       Paid       TS
# 4       1.056706e+15  2023.0  January    25  Lazada       Paid       TS
# ...              ...     ...      ...   ...     ...        ...      ...
# 150161  1.138044e+15  2023.0    April     7  Lazada       Paid  Gimmick
# 150162  1.137521e+15  2023.0    April     6  Lazada       Paid  Gimmick
# 150163  1.137138e+15  2023.0    April     6  Lazada       Paid  Gimmick
# 150164  1.130193e+15  2023.0    March    31  Lazada     Cancel   W'dank
# 150165  1.135182e+15  2023.0    April    13  Lazada     Unpaid       TS
#
#                      Sub Brand     Real SKU  \
# 0                     TS MERAH      2104405
# ...

# %%
import time
import pandas as pd
import numpy as np
import math

print('Start')

#TOKOPEDIA 2023
#tok1 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tok1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
print('Read Tokped 2023')
tok1 = tok1[tok1['Year'].isin([2023])][['Invoice','Year', 'Month', 'Date', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tok1['Price (Rp.)'] = pd.to_numeric(tok1['Price (Rp.)'],errors='coerce')
tok1['Discount Amount (Rp.)'] = pd.to_numeric(tok1['Discount Amount (Rp.)'],errors='coerce')
tok1['Total Net Before PPN'] = pd.to_numeric(tok1['Total Net Before PPN'],errors='coerce')
tok1['Qty. Invoiced'] = pd.to_numeric(tok1['Qty. Invoiced'],errors='coerce')
tok1['BTL Cost'] = pd.to_numeric(tok1['BTL Cost'].str.replace(',','.'),errors='coerce')
tok1['Selling Price'] = tok1['Price (Rp.)'] - tok1['Discount Amount (Rp.)']
tok1.drop(columns = ['Price (Rp.)', 'Discount Amount (Rp.)'], inplace = True)
tok1['Store'] = 'Tokopedia'
tok1['Order #'] = tok1['Invoice']
tok1 = tok1[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('TokPed 2023 Done')

#TOKOPEDIA 2022
#tok2 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Runningan Tokopedia Jan 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tok2 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Rev\Runningan Tokopedia Jan 23(1).csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
print('Read Tokped 2022')
tok2 = tok2[tok2['Year'].isin([2022])][['Invoice','Year', 'Month', 'Date', 'Paid January', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tok2['Price (Rp.)'] = pd.to_numeric(tok2['Price (Rp.)'],errors='coerce')
tok2['Discount Amount (Rp.)'] = pd.to_numeric(tok2['Discount Amount (Rp.)'],errors='coerce')
tok2['Total Net Before PPN'] = pd.to_numeric(tok2['Total Net Before PPN'],errors='coerce')
tok2['Qty. Invoiced'] = pd.to_numeric(tok2['Qty. Invoiced'],errors='coerce')
tok2['BTL Cost'] = pd.to_numeric(tok2['BTL Cost'].str.replace(',','.'),errors='coerce')
tok2['Selling Price'] = tok2['Price (Rp.)'] - tok2['Discount Amount (Rp.)']
tok2.drop(columns = ['Price (Rp.)', 'Discount Amount (Rp.)'], inplace = True)
tok2['Paid April'] = tok2['Paid January']
tok2['Store'] = 'Tokopedia'
tok2['Order #'] = tok2['Invoice']
tok2 = tok2[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('TokPed 2022 Done')

tok = pd.concat([tok1, tok2], ignore_index = True)
del tok1, tok2
print('Tokped Done')

#SHOPEE
#sopi = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Shopee By Selcen Jan 2022 - Apr 2023 rev1.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
sopi1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Shopee By Selcen Jan 2022 - Apr 2023 rev1.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'No. Pesanan' : str},  encoding='cp1252')
print('Read Sopi 2023')
sopi1 = sopi1[['No. Pesanan','Year', 'Month', 'Waktu Pesanan Dibuat', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Setelah Diskon', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
sopi1['Harga Setelah Diskon'] = pd.to_numeric(sopi1['Harga Setelah Diskon'],errors='coerce')
sopi1['Total Net Before PPN'] = pd.to_numeric(sopi1['Total Net Before PPN'],errors='coerce')
sopi1['Qty. Invoiced'] = pd.to_numeric(sopi1['Qty. Invoiced'],errors='coerce')
sopi1['BTL Cost'] = pd.to_numeric(sopi1['BTL Cost'].str.replace(',','.'),errors='coerce')
sopi1['Selling Price'] = sopi1['Harga Setelah Diskon'] * 100
sopi1['Date'] = sopi1['Waktu Pesanan Dibuat'].astype(str).str.slice(8, 10).astype(int)
sopi1.drop(columns = ['Harga Setelah Diskon'], inplace = True)
sopi1['Store'] = 'Shopee'
sopi1['Order #'] = sopi1['No. Pesanan']
sopi1 = sopi1[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]

sopi2 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Rev\Runningan Shopee By Selcen Jan 2022 - Jan 23.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'No. Pesanan' : str},  encoding='cp1252')
print('Read Sopi 2022')
sopi2 = sopi2[sopi2['Year'].isin([2022])]
sopi2['Paid April'] = sopi2['Paid January']
sopi2 = sopi2[['No. Pesanan','Year', 'Month', 'Waktu Pesanan Dibuat', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Setelah Diskon', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
sopi2['Harga Setelah Diskon'] = pd.to_numeric(sopi2['Harga Setelah Diskon'],errors='coerce')
sopi2['Total Net Before PPN'] = pd.to_numeric(sopi2['Total Net Before PPN'],errors='coerce')
sopi2['Qty. Invoiced'] = pd.to_numeric(sopi2['Qty. Invoiced'],errors='coerce')
sopi2['BTL Cost'] = pd.to_numeric(sopi2['BTL Cost'].str.replace(',','.'),errors='coerce')
sopi2['Selling Price'] = sopi2['Harga Setelah Diskon'] * 100
sopi2['Date'] = sopi2['Waktu Pesanan Dibuat'].astype(str).str.slice(8, 10).astype(int)
sopi2.drop(columns = ['Harga Setelah Diskon'], inplace = True)
sopi2['Store'] = 'Shopee'
sopi2['Order #'] = sopi2['No. Pesanan']
sopi2 = sopi2[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]

sopi = pd.concat([sopi1, sopi2], ignore_index = True)
del sopi1, sopi2
print('Shopee Done')

#LAZADA
#laz = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Running Lazada By Selcen Jan 22 - Apr 2023.xlsx",sheet_name = 'Running Lazada',converters = {'Phone' : str, 'Order #' : str})
laz1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Running Lazada By Selcen Jan 22 - Apr 2023.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Order Number' : str},  encoding='cp1252')
print('Read Laz')
laz1 = laz1[['Order Number', 'True datetime' ,'Year', 'Month', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Unit Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
laz1 = laz1[~laz1['True datetime'].isnull()]
laz1['Unit Price'] = pd.to_numeric(laz1['Unit Price'],errors='coerce')
laz1['Total Net Before PPN'] = pd.to_numeric(laz1['Total Net Before PPN'],errors='coerce')
laz1['Qty. Invoiced'] = pd.to_numeric(laz1['Qty. Invoiced'],errors='coerce')
laz1['BTL Cost'] = pd.to_numeric(laz1['BTL Cost'].str.replace(',','.'),errors='coerce')
laz1['True datetime'] = pd.to_datetime(laz1['True datetime'])
laz1['Date'] = laz1['True datetime'].astype(str).str.slice(8, 10).astype(int)
laz1.rename(columns = {'Unit Price' : 'Selling Price'}, inplace = True)
laz1['Store'] = 'Lazada'
laz1['Order #'] = laz1['Order Number']
laz1 = laz1[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Laz 2023 Done')

laz2 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Rev\Running Lazada By Selcen Jan 22 - Jan 2023.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Order Number' : str},  encoding='cp1252')
print('Read Laz')
laz2 = laz2[['Order Number', 'True datetime' ,'Year', 'Month', 'Paid January','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Unit Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
laz2 = laz2[laz2['Year'].isin([2022])]
laz2 = laz2[~laz2['True datetime'].isnull()]
laz2['Paid April'] = laz2['Paid January']
laz2['Unit Price'] = pd.to_numeric(laz2['Unit Price'],errors='coerce')
laz2['Total Net Before PPN'] = pd.to_numeric(laz2['Total Net Before PPN'],errors='coerce')
laz2['Qty. Invoiced'] = pd.to_numeric(laz2['Qty. Invoiced'],errors='coerce')
laz2['BTL Cost'] = pd.to_numeric(laz2['BTL Cost'].str.replace(',','.'),errors='coerce')
laz2['True datetime'] = pd.to_datetime(laz2['True datetime'])
laz2['Date'] = laz2['True datetime'].astype(str).str.slice(8, 10).astype(int)
laz2.rename(columns = {'Unit Price' : 'Selling Price'}, inplace = True)
laz2['Store'] = 'Lazada'
laz2['Order #'] = laz2['Order Number']
laz2 = laz2[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Laz 2022 Done')

laz = pd.concat([laz1, laz2], ignore_index = True)
del laz1, laz2
print('Laz Done')

#TIKTOK
tik = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Running TikTok Apr 2023.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
print('Read TikTok')
tik = tik[['Order #', 'Date' ,'Year', 'Month', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price List NFI', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tik.rename(columns = {'Price List NFI' : 'Selling Price'}, inplace = True)
tik['Store'] = 'TikTok'
tik = tik[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('TikTok Done')

#BLIBLI NM
blinm = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Blibli By Selcen Jan 22 - Apr 2023.xlsx",sheet_name = 'Runningan Blibli NM',converters = {'Phone' : str, 'No. Order' : str})
print('Read Bli NM')
blinm = blinm[['No. Order', 'Date' ,'Year', 'Month', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Produk', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
blinm.rename(columns = {'Harga Produk' : 'Selling Price'}, inplace = True)
blinm['Store'] = 'Blibli'
blinm['Order #'] = blinm['No. Order']
blinm = blinm[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk', 'Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Blibli NM Done')

#BLIBLI LMS
blilm = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Blibli L-Men By Selcen Jan 2022 - Apr 23.xlsx",sheet_name = 'Runningan Blibli L-Men',converters = {'Phone' : str, 'No. Order' : str})
print('Read Bli LMS')
blilm = blilm[['No. Order', 'Date' ,'Year', 'Month', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Produk', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
blilm.rename(columns = {'Harga Produk' : 'Selling Price'}, inplace = True)
blilm['Store'] = 'Blibli'
blilm['Order #'] = blilm['No. Order']
blilm = blilm[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk', 'Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Blibli LMS Done')

#BUKALAPAK
bl = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Bukalapak By Selcen Jan 2022 - Apr 23.xlsx",sheet_name = 'Runningan Bukalapak',converters = {'Phone' : str, 'ID Transaksi' : str})
print('Read Bukalapak')
bl = bl[['ID Transaksi','Order Date Seller Centre' ,'Year', 'Month', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Harga Produk', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
bl['Date'] = bl['Order Date Seller Centre'].astype(str).str.slice(8, 10).astype(int)
bl.rename(columns = {'Harga Produk' : 'Selling Price'}, inplace = True)
bl['Store'] = 'Bukalapak'
bl['Order #'] = bl['ID Transaksi']
bl = bl[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('BL Done')
# Out:
# Start
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_3276\2229822288.py:10: DtypeWarning: Columns (6,9,10,54,62,70,77,85,93,95,97,101,105,106,108,111,114,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   tok1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
# Read Tokped 2023
# TokPed 2023 Done
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_3276\2229822288.py:27: DtypeWarning: Columns (6,7,9,10,34,39,47,54,55,62,63,70,71,78,79,86,87,94,96,98,102,106,107,109,112,114,115,116,117,119,120,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   tok2 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Rev\Runningan Tokopedia Jan 23(1).csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
# Read Tokped 2022
# ...

# %%
#DATA TAHUN 2023
import numpy as np
import pandas as pd
import xlwt
import datetime as dt
pd.options.mode.chained_assignment = None
import datetime
from datetime import date

#Read CSV
df = pd.read_csv(r"D:\Masterdata\Clean Data\data_all_1 February With Order Online.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

#df = df[df['Year'].isin([2023])]
df['True datetime']=pd.to_datetime(df['True datetime'])
df['Real SKU']=df['Real SKU'].astype(str)
df['Phone']=df['Phone'].str.extract('(\d+)')
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_21088\70218772.py:11: DtypeWarning: Columns (12,15,20,24,25,27,29,30,31,32,33,34,35,36,37,39,53,54,57,59,60,66,67,73,74,80,81,87,88,94,95,101,102,108,122,123,134,135,136,153,159,161,167,168,169,172,173,174,175,176,180,181,183,196,197,198,199,200,201,202,203,205,209,210) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\Masterdata\Clean Data\data_all_1 February With Order Online.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

# %%
from datetime import date
osf=pd.read_excel(r"data_supp\order filter.xlsx")
df = df[df['Order Status'].isin(osf['order filter'].unique()) & df['Customer Name'].str.contains('ftl', case = False, na = False) & df['Store'].isin(['Nutrimart']) ]
#df['Store Type'].isin(['Organic']) &

# %%
df22[df22['Customer Name'].str.contains('ftl', case = False, na = False)][['Year','Month','Customer Name']].drop_duplicates()
# Out:
#            Year      Month Customer Name
# 182905   2022.0   February    FTL    FTL
# 365851   2022.0      March    FTL    FTL
# 461381   2022.0      April    FTL    FTL
# 808470   2022.0       June    FTL    FTL
# 1109997  2022.0     August    FTL    FTL
# 1237407  2022.0  September    FTL    FTL
# 1472620  2022.0    October    FTL    FTL
# 1594553  2022.0   November    FTL    FTL
# 1716907  2022.0   December    FTL    FTL

# %%
df3 = df1.groupby(['Month','Store','Channel','Warehouse Name','Brand','Real SKU','Real Nama Produk','Bundle Name']).agg({'Order #' : 'nunique', 'Total Net Before PPN' : 'sum','Qty. Invoiced' : 'sum'}).reset_index()
df3
# Out:
#            Month        Store      Channel     Warehouse Name         Brand  \
# 0          April  Aladin Mall  Aladin Mall  Primary Warehouse  Bonus Produk
# 1          April  Aladin Mall  Aladin Mall  Primary Warehouse          HiLo
# 2          April  Aladin Mall  Aladin Mall  Primary Warehouse          HiLo
# 3          April  Aladin Mall  Aladin Mall  Primary Warehouse          HiLo
# 4          April  Aladin Mall  Aladin Mall  Primary Warehouse          HiLo
# ...          ...          ...          ...                ...           ...
# 20306  September    Tokopedia    Tokopedia      toko cabang 4            TS
# 20307  September    Tokopedia    Tokopedia      toko cabang 4            TS
# 20308  September    Tokopedia    Tokopedia      toko cabang 4            TS
# 20309  September    Tokopedia    Tokopedia      toko cabang 4            TS
# 20310  September    Tokopedia    Tokopedia      toko cabang 4            TS
#
# ...

# %%
    with pd.ExcelWriter("data sales 2023.xlsx") as writer:  
        df2.to_excel(writer, sheet_name="Green Packing",index=False)
        df3.to_excel(writer, sheet_name="Raw Data",index=False)

# %%
# Out:
#                   Store             Warehouse Name
# 0                Blibli           Blibli Warehouse
# 153           Nutrimart          Primary Warehouse
# 430           Tokopedia        Tokopedia Warehouse
# 433              Shopee          Primary Warehouse
# 437              Lazada           Lazada Warehouse
# 470              TikTok              SSI Warehouse
# 500              Lazada          Primary Warehouse
# 544           Tokopedia          Primary Warehouse
# 1723             Lazada              FBL Warehouse
# 2045          Bukalapak          Primary Warehouse
# 2589       JD Indonesia          Primary Warehouse
# 39039       Aladin Mall          Primary Warehouse
# 559076           Shopee                        NaN
# 559087        Tokopedia                toko cabang
# 559091        Tokopedia              toko cabang 4
# 559167        Tokopedia                        NaN
# 559320           Lazada                        NaN
# ...

# %%
    with pd.ExcelWriter("data sales 2023.xlsx") as writer:  
        df2.to_excel(writer, sheet_name="raw data",index=False)

# %%
#DATA TAHUN 2022
import numpy as np
import pandas as pd
import xlwt
import datetime as dt
pd.options.mode.chained_assignment = None
import datetime
from datetime import date

#Read CSV
df22 = pd.read_csv(r"D:\Masterdata\Data Tahunan\data_all_2022.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

df22['True datetime']=pd.to_datetime(df22['True datetime'])
df22['Real SKU']=df22['Real SKU'].astype(str)
df22['Phone']=df22['Phone'].str.extract('(\d+)')
df22 = df22[df22['Year'].isin([2022])]
#df22 = df22[['Order #','Sales Order ID','Order Status','Order date','True datetime','Date','Month','Year','Store Type','Store','Customer Name','Phone','Brand','Sub Brand','Real SKU','Real Nama Produk','Parent Item','Bundle Name','Qty. Invoiced','Total Net Before PPN','Total']]
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_21088\3240179242.py:11: DtypeWarning: Columns (3,12,15,20,23,24,25,27,29,30,31,32,33,34,35,36,37,39,53,54,57,59,60,66,67,73,74,80,81,87,88,94,95,101,102,110,122,123,134,135,136,153,159,161,167,168,169,172,173,174,175,176,181,196,197,198,199) have mixed types. Specify dtype option on import or set low_memory=False.
#   df22 = pd.read_csv(r"D:\Masterdata\Data Tahunan\data_all_2022.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

# %%
from datetime import date
osf=pd.read_excel(r"data_supp\order filter.xlsx")
df22 = df22[df22['Order Status'].isin(osf['order filter'].unique()) & df22['Customer Name'].str.contains('ftl', case = False, na = False) & df22['Store'].isin(['Nutrimart']) ]

# %%
md = pd.concat([df,df22], ignore_index = True)

# %%
cust_1 = md.groupby(['Order #','Year','Month','Date','Store Type','Store','Channel','Coupon Code','Brand','Sub Brand','Real SKU','Real Nama Produk','Bundle Name','Customer Name','Customer Email','Phone','Payment Channel','City','Real Region'], dropna = False).agg({'Qty. Invoiced':'sum','Total Net Before PPN':'sum'}).reset_index()
cust_1
# Out:
#         Order #    Year     Month  Date Store Type      Store    Channel  \
# 0    1000098968  2022.0  February   9.0    Organic  Nutrimart  Nutrimart
# 1    1000098968  2022.0  February   9.0    Organic  Nutrimart  Nutrimart
# 2    1000098968  2022.0  February   9.0    Organic  Nutrimart  Nutrimart
# 3    1000100250  2022.0     March  16.0    Organic  Nutrimart  Nutrimart
# 4    1000101023  2022.0     April   2.0    Organic  Nutrimart  Nutrimart
# ..          ...     ...       ...   ...        ...        ...        ...
# 275  1000118823  2024.0   January  24.0    Organic  Nutrimart  Nutrimart
# 276  1000118873  2024.0   January  29.0    Organic  Nutrimart  Nutrimart
# 277  1000118873  2024.0   January  29.0    Organic  Nutrimart  Nutrimart
# 278  1000118874  2024.0   January  29.0    Organic  Nutrimart  Nutrimart
# 279  1000118874  2024.0   January  29.0    Organic  Nutrimart  Nutrimart
#
#      Coupon Code   Brand     Sub Brand  ...  \
# 0    JKTRSLA002B  Bundle        Bundle  ...
# ...

# %%
del df22, df

# %%
osf=pd.read_excel(r"data_supp\order filter.xlsx")
md = md[md['Order Status'].isin(osf['order filter'].unique())]
md1 = md[md['Brand'].isin(['NS','TS','HiLo','WDANK','L-Men']) & md['Store'].isin(['Lazada'])]
md1 = md1[['Order #','Year','Month','Date','Store','Brand','Sub Brand','Real SKU','Real Nama Produk','Bundle Name','Customer Name','Phone','Qty. Invoiced','Total Net Before PPN']]
md1

# %%
    with pd.ExcelWriter("FTL.xlsx") as writer:  
        cust_1.to_excel(writer, sheet_name="raw data",index=False)

# %%
all_data = pd.concat([tok, sopi, laz, tik, blinm, blilm, bl], ignore_index = True)
all_data = all_data[(all_data['Paid April'].isin(['Paid']))]
all_data['Order #'] = all_data['Order #'].astype(str)
all_data
# Out:
#                              Order #    Year    Month  Date      Store  \
# 0        INV/20230101/MPL/2942529446  2023.0  January     1  Tokopedia
# 1        INV/20230101/MPL/2942541549  2023.0  January     1  Tokopedia
# 2        INV/20230101/MPL/2942542425  2023.0  January     1  Tokopedia
# 3        INV/20230101/MPL/2942544990  2023.0  January     1  Tokopedia
# 4        INV/20230101/MPL/2942546098  2023.0  January     1  Tokopedia
# ...                              ...     ...      ...   ...        ...
# 2492482                 223225074561  2022.0  January    18  Bukalapak
# 2492483                 223225074756  2022.0  January    18  Bukalapak
# 2492484                 223225071639  2022.0  January    18  Bukalapak
# 2492485                 223221244239  2022.0  January     7  Bukalapak
# 2492486                 223222702281  2022.0  January    11  Bukalapak
#
#         Paid April    Brand               Sub Brand     Real SKU  \
# ...

# %%
ad1 = all_data[all_data['Brand'].isin(['L-Men','HiLo','TS','NS',"W'dank"])]
ad1
# Out:
#                              Order #    Year    Month  Date      Store  \
# 0        INV/20230101/MPL/2942529446  2023.0  January     1  Tokopedia
# 1        INV/20230101/MPL/2942541549  2023.0  January     1  Tokopedia
# 2        INV/20230101/MPL/2942542425  2023.0  January     1  Tokopedia
# 3        INV/20230101/MPL/2942544990  2023.0  January     1  Tokopedia
# 4        INV/20230101/MPL/2942546098  2023.0  January     1  Tokopedia
# ...                              ...     ...      ...   ...        ...
# 2492089                 223223755323  2022.0  January    14  Bukalapak
# 2492090                 223225430502  2022.0  January    19  Bukalapak
# 2492091                 223225430502  2022.0  January    19  Bukalapak
# 2492092                 223225430502  2022.0  January    19  Bukalapak
# 2492093                 223225430502  2022.0  January    19  Bukalapak
#
#         Paid April   Brand               Sub Brand    Real SKU  \
# ...

# %%
osf=pd.read_excel(r"data_supp\order filter.xlsx")
md = md[md['Order Status'].isin(osf['order filter'].unique())]

# %%
md['Month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
#HiLo

# %%
sku_hilo = pd.read_excel(r"C:\Users\steven.nathanael\OneDrive - PT Nutrifood Indonesia\sku hilo.xlsx",sheet_name = 'Sheet1')
sku_hilo['Real SKU'] = sku_hilo['SKU']
sku_hilo
# Out:
#              SKU Brand                                        Nama Produk  \
# 0     2101478180  HiLo                     HiLo Active Caramel Latte 500g
# 1     2101452195  HiLo                      HiLo Active Chocolate 1000 gr
# 2     2101452180  HiLo                        HiLo Active Chocolate 500gr
# 3     2101452190  HiLo                        HiLo Active Chocolate 750gr
# 4     2101485195  HiLo                          HiLo Active Vanilla 1000g
# ..           ...   ...                                                ...
# 63  2101642180P2  HiLo  Twin Pack - HiLo Teen Popcorn Caramel 500 gram...
# 64  2101683180P2  HiLo    Twin Pack - HiLo Teen Strawberry Milkshake 500g
# 65  2101609180P2  HiLo                   Twin Pack - HiLo Teen Taro 500gr
# 66  2101684190P2  HiLo                Twin Pack - HiLo Teen Vanilla 750gr
# 67  2101684180P2  HiLo        Twin Pack - HiLo Teen Vanilla Caramel 500gr
#
#    Sub Brand  Gramasi   Paket      Real SKU
# ...

# %%
df_h = pd.merge(ad1, sku_hilo[['Real SKU','Gramasi']], on = ['Real SKU'], how = 'inner')
df_h = pd.merge(df_h,md[['Order #', 'Real SKU', 'Qty. Invoiced','Bundle Name']], on = ['Order #', 'Real SKU', 'Qty. Invoiced'], how = 'left')
df_h = df_h[(~df_h['Gramasi'].isnull()) & (~df_h['Bundle Name'].str.contains('Buy|Package|Paket|Platinum|WHS|&|JBL|Glukosamin', na = False, case = False)) & (~df_h['Bundle Name'].isin(['Chocolate','Vanilla']))]
df_h
# Out:
#                             Order #    Year    Month  Date      Store  \
# 0       INV/20230101/MPL/2942529446  2023.0  January     1  Tokopedia
# 1       INV/20230101/MPL/2942735250  2023.0  January     1  Tokopedia
# 2       INV/20230101/MPL/2943207934  2023.0  January     1  Tokopedia
# 3       INV/20230101/MPL/2943509509  2023.0  January     1  Tokopedia
# 4       INV/20230101/MPL/2943894076  2023.0  January     1  Tokopedia
# ...                             ...     ...      ...   ...        ...
# 241098                 223222915401  2022.0  January    12  Bukalapak
# 241099                 223222916436  2022.0  January    12  Bukalapak
# 241100                 223222916790  2022.0  January    12  Bukalapak
# 241101                 223273501878  2022.0      May    23  Bukalapak
# 241102                 223222272054  2022.0  January    10  Bukalapak
#
#        Paid April Brand  Sub Brand    Real SKU             Real Nama Produk  \
# ...

# %%
md[md['Real SKU'].isin(['2191845360'])]
# Out:
# Empty DataFrame
# Columns: [Order #, Sales Order ID, Order Status, Order date, True datetime, Date, Month, Year, Store Type, Store, Customer Name, Phone, Brand, Sub Brand, Real SKU, Real Nama Produk, Parent Item, Bundle Name, Qty. Invoiced, Total Net Before PPN, Total]
# Index: []
#
# [0 rows x 21 columns]

# %%
#Regulasi April

# %%
lock_sku = ['2101845360','2101888360','21014281','2HF1401250','2101819360',
             '2101656','2101847360','2307061250','1101685360','1101656360','1101569360',
             '1102070350','2102900125','2102040225','2104523105','2105500225','2104394210',
             '2106395308','2104406','2104170164','2101947250','2101941250','2303054155',
             '2306551173','2101453604','2104251230','2154084141','2HF0111003','2101651604',
             '2304051151','2304558112']

# %%
ad1['Brand'].unique()
# Out:
# array(['HiLo', 'L-Men', 'TS', 'NS'], dtype=object)

# %%
df_ra = ad1[ad1['Real SKU'].isin(lock_sku)]
df_ra.loc[df_ra['Real SKU'].isin(['21014281']), 'Real SKU'] = '2HF1401250'
df_ra = df_ra[df_ra['Year'].isin([2023])]

# %%
df_ra['Brand'].unique()
# Out:
# array(['TS', 'NS', 'HiLo', 'L-Men', "W'dank"], dtype=object)

# %%
#Naik Harga

# %%
sku_naik = pd.read_excel(r"C:\Users\steven.nathanael\OneDrive - PT Nutrifood Indonesia\Documents\SKU Naik Harga.xlsx")
sku_naik
#sku_naik = sku_naik['SKU Naik Harga'].unique()
# Out:
#     SKU Naik Harga
# 0       2307061250
# 1       2303054155
# 2       2303056180
# 3       2306551173
# 4       2300551155
# ..             ...
# 193     2101813443
# 194     2101845443
# 195     2101864443
# 196     2101865450
# 197     2HF0111003
#
# [198 rows x 1 columns]

# %%
df_nh['Brand'].unique()
# Out:
# array(['HiLo', 'TS', "W'dank", 'L-Men', 'NS'], dtype=object)

# %%
df_nh = ad1[ad1['Real SKU'].isin(sku_naik['SKU Naik Harga'].unique())]
df_nh = df_nh[~(df_nh['Year'].isin([2022]) & df_nh['Month'].isin(['January','February','March','April','May','July']))]

# %%
    with pd.ExcelWriter(r"PPT Data3.xlsx") as writer:  
        df_h.to_excel(writer, sheet_name="HiLo",index=False)
        df_nh.to_excel(writer, sheet_name="Naik Harga Feb",index=False)
        df_ra.to_excel(writer, sheet_name="Regulasi Apr",index=False)
        md1_1.to_excel(writer, sheet_name="Masterdata Jan 22 - Agu 22",index=False)
        md1_2.to_excel(writer, sheet_name="Masterdata Sep 22 - Apr 23",index=False)

# %%
md1_1 = md1[md1['True datetime'] < '2022-09-01']
md1_2 = md1[md1['True datetime'] >= '2022-09-01']

# %%
md1 = md[md['Store Type'].isin(['Marketplace']) & md['Brand'].isin(['HiLo','TS','NS','WDANK','L-Men'])]
md1
# Out:
#                              Order # Sales Order ID      Order Status  \
# 2                        12121396731    12170324721         Delivered
# 4                        12121385635    12170309027  Sudah Settlement
# 6                        12121413238    12170350531  Sudah Settlement
# 7                        12121409053    12170344246  Sudah Settlement
# 8                        12121385758    12170309208  Sudah Settlement
# ...                              ...            ...               ...
# 2517318  INV/20221231/MPL/2941648921   SO-128112720         Completed
# 2517319           576907205589108751   SO-128112461         Completed
# 2517320  INV/20221231/MPL/2941368541   SO-128109832         Completed
# 2517321  INV/20221231/MPL/2942125333   SO-128116824         Completed
# 2517322  INV/20221231/MPL/2941648921   SO-128112720         Completed
#
#                   Order date       True datetime  Date     Month    Year  \
# ...

# %%
md1_2['Month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'September',
#        'October', 'November', 'December'], dtype=object)

# %%
#LAZADA
#laz = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Running Lazada By Selcen Jan 22 - Apr 2023.xlsx",sheet_name = 'Running Lazada',converters = {'Phone' : str, 'Order #' : str})
laz1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Running Lazada By Selcen Jan 22 - Apr 2023.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Order Number' : str},  encoding='cp1252')
print('Read Laz')
laz1 = laz1[['Order Number', 'True datetime' ,'Year', 'Month', 'Customer Name', 'Shipping Name', 'Paid April','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Unit Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
laz1 = laz1[~laz1['True datetime'].isnull()]
laz1['Unit Price'] = pd.to_numeric(laz1['Unit Price'],errors='coerce')
laz1['Total Net Before PPN'] = pd.to_numeric(laz1['Total Net Before PPN'],errors='coerce')
laz1['Qty. Invoiced'] = pd.to_numeric(laz1['Qty. Invoiced'],errors='coerce')
laz1['BTL Cost'] = pd.to_numeric(laz1['BTL Cost'].str.replace(',','.'),errors='coerce')
laz1['True datetime'] = pd.to_datetime(laz1['True datetime'])
laz1['Date'] = laz1['True datetime'].astype(str).str.slice(8, 10).astype(int)
laz1.rename(columns = {'Unit Price' : 'Selling Price'}, inplace = True)
laz1['Store'] = 'Lazada'
laz1['Order #'] = laz1['Order Number'].astype(str)
laz1 = laz1[['Order #', 'Year', 'Month', 'Date', 'Store', 'Customer Name', 'Shipping Name','Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Laz 2023 Done')

laz2 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Rev\Running Lazada By Selcen Jan 22 - Jan 2023.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Order Number' : str},  encoding='cp1252')
print('Read Laz')
laz2 = laz2[['Order Number', 'True datetime' ,'Year', 'Month', 'Customer Name', 'Shipping Name', 'Paid January','Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Unit Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
laz2 = laz2[laz2['Year'].isin([2022])]
laz2 = laz2[~laz2['True datetime'].isnull()]
laz2['Paid April'] = laz2['Paid January']
laz2['Unit Price'] = pd.to_numeric(laz2['Unit Price'],errors='coerce')
laz2['Total Net Before PPN'] = pd.to_numeric(laz2['Total Net Before PPN'],errors='coerce')
laz2['Qty. Invoiced'] = pd.to_numeric(laz2['Qty. Invoiced'],errors='coerce')
laz2['BTL Cost'] = pd.to_numeric(laz2['BTL Cost'].str.replace(',','.'),errors='coerce')
laz2['True datetime'] = pd.to_datetime(laz2['True datetime'])
laz2['Date'] = laz2['True datetime'].astype(str).str.slice(8, 10).astype(int)
laz2.rename(columns = {'Unit Price' : 'Selling Price'}, inplace = True)
laz2['Store'] = 'Lazada'
laz2['Order #'] = laz2['Order Number'].astype(str)
laz2 = laz2[['Order #', 'Year', 'Month', 'Date', 'Store', 'Customer Name', 'Shipping Name','Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('Laz 2022 Done')

laz = pd.concat([laz1, laz2], ignore_index = True)
del laz1, laz2
print('Laz Done')
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_3276\263633676.py:3: DtypeWarning: Columns (0,1,3,4,5,6,9,10,13,14,16,17,18,21,23,25,33,35,37,38,39,41,42,44,45,46,48,54,55,63,64,65,67,68,69,71,74,75,77,78,79,80,82,85,86,92,96,97,101,102,104,105,106,107,108,109,110,111,117,118,124,125,131,132,138,139,145,152,161,163,164,166,168,169,170,171,172,173,174,175,176,177,179,180,181,182,183,184,185,186) have mixed types. Specify dtype option on import or set low_memory=False.
#   laz1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Running Lazada By Selcen Jan 22 - Apr 2023.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Order Number' : str},  encoding='cp1252')
# Read Laz
# Laz 2023 Done
# ...

# %%
df_h1 = pd.merge(laz, sku_hilo[['Real SKU','Gramasi']], on = ['Real SKU'], how = 'inner')
df_h1 = pd.merge(df_h1,md[['Order #', 'Real SKU', 'Qty. Invoiced','Bundle Name']], on = ['Order #', 'Real SKU', 'Qty. Invoiced'], how = 'left')
df_h1 = df_h1[(~df_h1['Gramasi'].isnull()) & (~df_h1['Bundle Name'].str.contains('Buy|Package|Paket|Platinum|WHS|&|JBL|Glukosamin', na = False, case = False)) & (~df_h1['Bundle Name'].isin(['Chocolate','Vanilla']))]
df_h1['Unique Cust'] = df_h1['Customer Name'] + df_h1['Shipping Name']

# %%
NR = df_h1.drop_duplicates('Order #')[['Order #','Year','Month','Date','Unique Cust']].sort_values(by = ['Year', 'Month', 'Date'], ascending = True)
NR['cust_time'] = NR.groupby(['Unique Cust']).cumcount()
NR['cust_type'] = NR['cust_time'].apply(lambda x: 'New' if (x == 0) else 'Return')

df_h2 = pd.merge(df_h1,
                 NR[['Order #','cust_time','cust_type']], 
                 on ='Order #',
                 how = 'left')
df_h2
# Out:
#                 Order #    Year    Month  Date   Store    Customer Name  \
# 0      1056705138014070  2023.0  January    25  Lazada            vitri
# 1      1054992350452926  2023.0  January    24  Lazada  Apri Dianingsih
# 2      1054685366557491  2023.0  January    23  Lazada       ida royati
# 3      1053838562463721  2023.0  January    22  Lazada     cahyahidayat
# 4      1053116386407638  2023.0  January    21  Lazada    **********388
# ...                 ...     ...      ...   ...     ...              ...
# 67363   775468029448752  2022.0  January    18  Lazada      Merinda DND
# 67364   775367802047603  2022.0  January    18  Lazada            Melva
# 67365   773500808713065  2022.0  January    15  Lazada    Dita Fajriani
# 67366   786712555476781  2022.0  January    25  Lazada             Dian
# 67367  1140681103948465  2023.0    April     8  Lazada     Hanif Azhari
#
#         Shipping Name Paid April   Brand  Sub Brand  ...  \
# ...

# %%
    with pd.ExcelWriter(r"PPT Data3.xlsx") as writer:  
        df_h2.to_excel(writer, sheet_name="HiLo",index=False)

# %%
md1
# Out:
#                              Order # Sales Order ID      Order Status  \
# 2                        12121396731    12170324721         Delivered
# 4                        12121385635    12170309027  Sudah Settlement
# 6                        12121413238    12170350531  Sudah Settlement
# 7                        12121409053    12170344246  Sudah Settlement
# 8                        12121385758    12170309208  Sudah Settlement
# ...                              ...            ...               ...
# 2517318  INV/20221231/MPL/2941648921   SO-128112720         Completed
# 2517319           576907205589108751   SO-128112461         Completed
# 2517320  INV/20221231/MPL/2941368541   SO-128109832         Completed
# 2517321  INV/20221231/MPL/2942125333   SO-128116824         Completed
# 2517322  INV/20221231/MPL/2941648921   SO-128112720         Completed
#
#                   Order date       True datetime  Date     Month    Year  \
# ...

# %%
md2 = md1[md1['Store'].isin(['Lazada']) & (md1['Date'] <= 16)]
md2.groupby(['Year','Month']).agg({'Phone' : 'nunique',
                                   'Order #' : 'nunique'})
# Out:
#                   Phone  Order #
# Year   Month
# 2022.0 April      11134    12132
#        August      5861     7077
#        December    6901    10213
#        February   11731    12735
#        January     2944     3244
#        July        4953     6149
#        June        6586     7432
#        March       7049     7781
#        May         6003     6678
#        November    7003    10121
#        October     6279     7855
#        September   7255     9249
# 2023.0 April       7344     9589
#        February    5824     7323
#        January     2457     2801
#        March       7506     9257
#        May          660      709

# %%
md1['Tokopedia']
# Out:
#                   Order # Sales Order ID Order Status           Order date  \
# 545      1037900176135508   SO-128159037    Delivered  2023-01-01 23:25:00
# 660      1028793494465526   SO-128157864    Completed  2023-01-01 22:53:00
# 681      1028802859011977   SO-128157797    Delivered  2023-01-01 22:51:00
# 730      1028797449709789   SO-128157399    Delivered  2023-01-01 22:39:00
# 731      1037873787803272   SO-128157398    Delivered  2023-01-01 22:39:00
# ...                   ...            ...          ...                  ...
# 2517223  1036500598596946   SO-128106859    Delivered  2022-12-31 09:50:00
# 2517246  1036456794682702   SO-128105554    Delivered  2022-12-31 08:41:00
# 2517302  1027904014391681   SO-128119233    Delivered  2022-12-31 21:39:00
# 2517304  1036856917708649   SO-128116158    Delivered  2022-12-31 18:06:00
# 2517314  1027457470613346   SO-128107215    Delivered  2022-12-31 10:10:00
#
# ...

# %%
import time
import pandas as pd
import numpy as np
import math

print('Start')

#TOKOPEDIA 2023
#tok1 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tok1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
print('Read Tokped 2023')
tok1 = tok1[tok1['Year'].isin([2023])][['Invoice','Year', 'Month', 'Date', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tok1['Price (Rp.)'] = pd.to_numeric(tok1['Price (Rp.)'],errors='coerce')
tok1['Discount Amount (Rp.)'] = pd.to_numeric(tok1['Discount Amount (Rp.)'],errors='coerce')
tok1['Total Net Before PPN'] = pd.to_numeric(tok1['Total Net Before PPN'],errors='coerce')
tok1['Qty. Invoiced'] = pd.to_numeric(tok1['Qty. Invoiced'],errors='coerce')
tok1['BTL Cost'] = pd.to_numeric(tok1['BTL Cost'].str.replace(',','.'),errors='coerce')
tok1['Selling Price'] = tok1['Price (Rp.)'] - tok1['Discount Amount (Rp.)']
tok1.drop(columns = ['Price (Rp.)', 'Discount Amount (Rp.)'], inplace = True)
tok1['Store'] = 'Tokopedia'
tok1['Order #'] = tok1['Invoice']
tok1 = tok1[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('TokPed 2023 Done')

#TOKOPEDIA 2022
#tok2 = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Runningan Tokopedia Jan 23.xlsx",sheet_name = 'Sheet1',converters = {'Phone' : str, 'Order #' : str})
tok2 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Rev\Runningan Tokopedia Jan 23(1).csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
print('Read Tokped 2022')
tok2 = tok2[tok2['Year'].isin([2022])][['Invoice','Year', 'Month', 'Date', 'Paid January', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk',  'Price (Rp.)', 'Discount Amount (Rp.)', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
tok2['Price (Rp.)'] = pd.to_numeric(tok2['Price (Rp.)'],errors='coerce')
tok2['Discount Amount (Rp.)'] = pd.to_numeric(tok2['Discount Amount (Rp.)'],errors='coerce')
tok2['Total Net Before PPN'] = pd.to_numeric(tok2['Total Net Before PPN'],errors='coerce')
tok2['Qty. Invoiced'] = pd.to_numeric(tok2['Qty. Invoiced'],errors='coerce')
tok2['BTL Cost'] = pd.to_numeric(tok2['BTL Cost'].str.replace(',','.'),errors='coerce')
tok2['Selling Price'] = tok2['Price (Rp.)'] - tok2['Discount Amount (Rp.)']
tok2.drop(columns = ['Price (Rp.)', 'Discount Amount (Rp.)'], inplace = True)
tok2['Paid April'] = tok2['Paid January']
tok2['Store'] = 'Tokopedia'
tok2['Order #'] = tok2['Invoice']
tok2 = tok2[['Order #', 'Year', 'Month', 'Date', 'Store', 'Paid April', 'Brand', 'Sub Brand', 'Real SKU', 'Real Nama Produk','Selling Price', 'Total Net Before PPN', 'Qty. Invoiced', 'BTL Cost']]
print('TokPed 2022 Done')

tok = pd.concat([tok1, tok2], ignore_index = True)
del tok1, tok2
print('Tokped Done')

# %%
tok1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
tok1
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_3276\4147111838.py:1: DtypeWarning: Columns (6,9,10,54,62,70,77,85,93,95,97,101,105,106,108,111,114,116,119,120) have mixed types. Specify dtype option on import or set low_memory=False.
#   tok1 = pd.read_csv(r"C:\Users\steven.nathanael\Downloads\Apr 2023\Runningan Tokopedia Apr 23.csv", sep = ';', index_col = False, converters = {'Phone' : str, 'Invoice' : str}, encoding='cp1252')
#         Order ID                      Invoice         Payment Date  \
# 0            NaN  INV/20230101/MPL/2942529446  01-01-2023 00:05:19
# 1            NaN  INV/20230101/MPL/2942541549  01-01-2023 00:19:33
# 2            NaN  INV/20230101/MPL/2942542425  01-01-2023 00:20:32
# 3            NaN  INV/20230101/MPL/2942544990  01-01-2023 00:23:14
# 4            NaN  INV/20230101/MPL/2942546098  01-01-2023 00:24:27
# ...          ...                          ...                  ...
# 175965       NaN  INV/20230421/MPL/3190799571  21-04-2023 21:50:13
# ...

# %%
import time
import pandas as pd
import numpy as np
import math

df = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Business Advisor - Product - Performance  (3).xls",converters = {'Seller SKU' : str}, skiprows=5)
df1 = df[df['Seller SKU'].isin(['-'])].drop(columns = ['Seller SKU','SKU ID'])
df2 = df[~df['Seller SKU'].isin(['-'])]
df3 = pd.merge(df2[['Product Name','Product ID','Seller SKU']], df1[['Product Name','Product ID','Visitors','Product Pageviews','Buyers','Orders','Units Sold']], on = ['Product Name','Product ID'], how = 'left')
df3 = df3[~df3['Visitors'].isnull()]
with pd.ExcelWriter(r"LSS Laz Maret.xlsx") as writer:  
    df3.to_excel(writer, sheet_name="Raw",index=False)

# %%
df3 = pd.merge(df2[['Product Name','Product ID','Seller SKU']], df1[['Product Name','Product ID','Visitors','Product Pageviews','Buyers','Orders','Units Sold']], on = ['Product Name','Product ID'], how = 'left')
df3 = df3[~df3['Visitors'].isnull()]
df3
# Out:
#                                           Product Name  Product ID  \
# 0    NutriSari American Sweet Orange 160 sachet - M...   670676200
# 1    NutriSari American Sweet Orange 40 Sachet - Mi...   938640389
# 2    HiLo Teen Vanilla Caramel 750g - Susu Tinggi K...     1090821
# 3    Tropicana Slim Minyak Kanola 946ml -  100% Pur...   146185445
# 4    Tropicana Slim Sweetener Diabtx 100 Sachet - P...     1064280
# ..                                                 ...         ...
# 494  Tea Time Package - Tropicana Slim Sweetener Ro...  5662714161
# 495  Paket Kalsium Keluarga - HiLo Active Chocolate...  5207444772
# 499  12 Days Lose Weight - L-Men Lose Weight Chocol...  4343962728
# 500  Twin Pack - L-Men Platinum Choco latte Dus 6 S...  2309202150
# 501  HiLo UHT Kacang Hijau RTD  [24 pcs x 200ml] - ...  1389786964
#
#         Seller SKU Visitors Product Pageviews  Buyers  Orders  Units Sold
# 0     1101909331P4     1142              3806   229.0   303.0       510.0
# ...

# %%
    with pd.ExcelWriter(r"LSS Laz Maret.xlsx") as writer:  
        df3.to_excel(writer, sheet_name="Raw",index=False)

# %%
df3[df3['Product Name'].str.contains('Bajigur', na = False, case = False)]
# Out:
#                                          Product Name  Product ID  Seller SKU  \
# 32  NutriSari W'dank Bajigur 10 sachet - Minuman T...     2939123  1101665318
#
#    Visitors Product Pageviews  Buyers  Orders  Units Sold
# 32     2339              7250   324.0   378.0       979.0

# %%
#BENERIN LAZ

# %%
### Cek Gudang Laz
laz = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Running Lazada By Selcen Jan 23 - May 2023.xlsx" ,sheet_name = 'Running Lazada',converters = {'Order Number' : str})

# %%
laz1 = laz[~laz['WH'].isnull()][['Order Number','Real SKU','WH']]
laz1['WH'] = laz1['WH'].str.replace('Telkom','Primary Warehouse')
laz1.rename(columns = {'WH' : 'Warehouse Name New',
                       'Order Number' : 'Order #'}, inplace = True)
laz1['Unique Order'] = laz1['Order #'] + '_' + laz1['Real SKU']

# %%
laz[laz['Order Number'].isin(['1150919762923659'])]
# Out:
#            Order Item Id Order Type  Order Flag         Lazada Id         SKU  \
# 174667  1150919763023659     NORMAL         NaN  1150919763023659  1N03301456
# 174668  1150919763123659     NORMAL         NaN  1150919763123659  1N03301456
# 174669  1150919763223659     NORMAL         NaN  1150919763223659  1N03301456
# 174670  1150919763323659     NORMAL         NaN  1150919763323659  1N03301456
#
#                        Product ID Order Date Seller Centre  Updated at  \
# 174667  7396420921_ID-13809940512        24 Apr 2023 08:07         NaN
# 174668  7396420921_ID-13809940512        24 Apr 2023 08:07         NaN
# 174669  7396420921_ID-13809940512        24 Apr 2023 08:07         NaN
# 174670  7396420921_ID-13809940512        24 Apr 2023 08:07         NaN
#
#             Order Number Invoice Required  ... Total Transfer  Order No.  \
# 174667  1150919762923659               No  ...        37500.0        NaN
# ...

# %%
laz1[laz1['Unique Order'].isin(['1150919762923659_1N03301456'])]
# Out:
#                  Order #    Real SKU Warehouse Name New  \
# 174667  1150919762923659  1N03301456   Lazada Warehouse
# 174668  1150919762923659  1N03301456   Lazada Warehouse
# 174669  1150919762923659  1N03301456   Lazada Warehouse
# 174670  1150919762923659  1N03301456   Lazada Warehouse
#
#                        Unique Order
# 174667  1150919762923659_1N03301456
# 174668  1150919762923659_1N03301456
# 174669  1150919762923659_1N03301456
# 174670  1150919762923659_1N03301456

# %%
dfl = df[df['Store'].isin(['Lazada'])]
dfl['Unique Order'] = dfl['Order #'] + '_' + dfl['Real SKU']

# %%
dfl1 = pd.merge(dfl, laz1[['Unique Order','Warehouse Name New']], on = 'Unique Order', how = 'left')
dfl1.loc[dfl1['Warehouse Name New'].isnull(), 'Warehouse Name New'] = dfl1['Warehouse Name']
dfl1.loc[dfl1['Warehouse Name New'].isin(['Lazada Warehouse']), 'Warehouse Name New'] = 'FBL Warehouse'

# %%
dfl1['Warehouse Name'] = dfl1['Warehouse Name New']
dfl1.drop(columns = ['Unique Order', 'Warehouse Name New'], inplace = True)
dfl1
# Out:
#                  Order # Sales Order ID              AWB  Paid Date  \
# 0       1037925735540886   SO-128160176  LXAT-1003502330        NaN
# 1       1037925735540886   SO-128160176  LXAT-1003502330        NaN
# 2       1037921134200311   SO-128159804  LXAT-1003502355        NaN
# 3       1037918924816615   SO-128159574  LXAD-2789755893        NaN
# 4       1037900176135508   SO-128159037  LXAD-2789755839        NaN
# ...                  ...            ...              ...        ...
# 190418  1166126081617959   SO-132537025  LXAD-2952131074        NaN
# 190419  1176692912217959   SO-132536990  LXAD-2952131170        NaN
# 190420  1168705263734248   SO-132611967  LXAD-2957050211        NaN
# 190421  1166126081617959   SO-132537025  LXAD-2952131074        NaN
# 190422  1176692912217959   SO-132536990  LXAD-2952131170        NaN
#
#        Order Status           Order date  Week  Date    Month  Quarter  ...  \
# ...

# %%
df1 = df[~df['Store'].isin(['Lazada'])]
df1 = df1.append(dfl1, ignore_index = True)
df1
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_27316\1489169436.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(dfl1, ignore_index = True)
#                  Order # Sales Order ID                 AWB  Paid Date  \
# 0            12121413238    12170350531    BLI2209226577020        NaN
# 1            12121409053    12170344246    BLI2209227755413        NaN
# 2            12121396731    12170324721  BLIGI00049654681-1        NaN
# 3            12121385758    12170309208    BLI1510222741567        NaN
# 4            12121385635    12170309027    8811622233348591        NaN
# ...                  ...            ...                 ...        ...
# 828119  1166126081617959   SO-132537025     LXAD-2952131074        NaN
# 828120  1176692912217959   SO-132536990     LXAD-2952131170        NaN
# 828121  1168705263734248   SO-132611967     LXAD-2957050211        NaN
# ...

# %%
osf=pd.read_excel(r"data_supp\order filter.xlsx")
df1.loc[df1['Store']=='Blibli','Warehouse Name']='Blibli Warehouse'
df1.loc[df1['Store'].isin(['Shoppee', 'TikTok']),'Warehouse Name']='SSI Warehouse'
df1[(df1['True datetime']>='2023-01-01')&(df1['Order Status'].isin(osf['order filter'].unique()))][['Sales Order ID','Order #','Order Status','Year','Month','Week','Date','Store Type','Store',
                                                  'Channel','Brand','Real SKU','Real Nama Produk','Bundle Name','Qty. Invoiced',
                                                  'Total Net Before PPN','Total','Coupon Code','Customer Name','Customer Email',
                                                  'Phone','Address','Warehouse Name','City','Region','Region Group','Real Region']].to_excel(f'D:\Masterdata\Masterdata Lite\Masterdata Lite Order {date.today()}.xlsx',index=False)

# %%
#TOKOPEDIA SEMENTARA

# %%
for i in df.columns:
    print(i)
# Out:
# Order #
# Sales Order ID
# AWB
# Paid Date
# Order Status
# Order date
# Week
# Date
# Month
# Quarter
# Year
# Channel
# SKU
# Brand
# Product Name
# Bundle Name
# Price List NFI
# Qty. Invoiced
# Total Net
# Sub Brand
# Real SKU
# Real Nama Produk
# Parent Item
# Parent SKU
# Bundle Flag
# Customer Email
# Customer Name
# Customer Group
# Phone
# Country
# Region
# City
# Kecamatan
# Kelurahan
# Address
# Zip Code
# Shipping Name
# Shipping Courier
# Total
# Coupon Code
# Qty. Ordered
# Qty. Shipped
# Qty. Refunded
# Item Price
# Subtotal
# Discounts
# Tax
# Total incl. Tax
# Invoiced
# Tax Invoiced
# Invoiced incl. Tax
# Refunded
# Refunded incl. Tax
# Cart Name Rule
# Payment Channel
# Voucher Amount
# Discount Poin Reward
# Ship Date
# Discount Product
# Produk 1
# SKU Produk 1
# PCS Produk 1
# Price List NFI 1
# Subtotal Produk 1
# Harga Display 1
# Harga Cost 1
# Produk 2
# SKU Produk 2
# PCS Produk 2
# Price List NFI 2
# Subtotal Produk 2
# Harga Display 2
# Harga Cost 2
# ...

# %%
tok=pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Tokopedia_Order_20230530-20230531.xlsx")
tok.rename(columns = {'Nomor Invoice' : 'Order #',
                      'Nomor SKU' : 'Real SKU',
                      'Jumlah Produk Dibeli' : 'Qty. Invoiced',
                      'Nama Produk' : 'Product Name',
                      'Nama Pembeli' : 'Customer Name',
                      'No Telp Pembeli' : 'Phone',
                      'Alamat Pengiriman' : 'Address',
                      'Kota' : 'City',
                      'Provinsi' : 'Region',
                      'Gudang Pengiriman' : 'Warehouse Name',
                      'Nama Kurir' : 'Shipping Courier',
                      'No Resi / Kode Booking' : 'AWB',
                      'Status Terakhir' : 'Order Status',
                      'Total Penjualan' : 'Total',
                      'Harga Jual' : 'Selling Price'}, inplace = True)

# %%
tok['Day'] = tok['Tanggal Pembayaran'].str.slice(0, 2).astype(int)
tok['Month'] = tok['Tanggal Pembayaran'].str.slice(3, 5).astype(int)
tok['Year'] = tok['Tanggal Pembayaran'].str.slice(6, 10).astype(int)
tok['Hour'] = tok['Tanggal Pembayaran'].str.slice(11, 13).astype(int)
tok['Minute'] = tok['Tanggal Pembayaran'].str.slice(14, 16).astype(int)
tok['Second'] = tok['Tanggal Pembayaran'].str.slice(17, 20).astype(int)
tok['True datetime'] = pd.to_datetime(tok[['Year','Month','Day','Hour','Minute','Second']])
tok['Month'] = tok['Month'].apply(lambda x : 'September' if x == 9 else
                                            ('October' if x == 10 else
                                            ('November' if x == 11 else 
                                            ('December' if x == 12 else
                                            ('January' if x == 1 else
                                            ('February' if x == 2 else
                                            ('March' if x == 3 else
                                            ('April' if x == 4 else
                                            ('May' if x == 5 else
                                            ('June' if x == 6 else
                                            ('July' if x == 7 else 'August')))))))))))
tok.rename(columns = {'Day' : 'Date'}, inplace = True)

# %%
tok
# Out:
#        Nomor                      Order #   Tanggal Pembayaran  \
# 0        1.0  INV/20230530/MPL/3261138134  30-05-2023 00:02:33
# 1        2.0  INV/20230530/MPL/3261139940  30-05-2023 00:05:14
# 2        3.0  INV/20230530/MPL/3261141243  30-05-2023 00:07:19
# 3        4.0  INV/20230530/MPL/3261143193  30-05-2023 00:10:07
# 4        5.0  INV/20230530/MPL/3261144058  30-05-2023 00:11:30
# ...      ...                          ...                  ...
# 2108     NaN  INV/20230531/MPL/3265172468  31-05-2023 23:49:12
# 2109  1647.0  INV/20230531/MPL/3265182109  31-05-2023 23:56:02
# 2110  1648.0  INV/20230531/MPL/3265183025  31-05-2023 23:57:11
# 2111  1649.0  INV/20230531/MPL/3265154998  31-05-2023 23:57:17
# 2112     NaN  INV/20230531/MPL/3265154998  31-05-2023 23:57:17
#
#            Order Status Tanggal Pesanan Selesai Waktu Pesanan Selesai  \
# 0       Pesanan Selesai              01-06-2023              23:39:00
# ...

# %%
#ISOPOWER
osf=pd.read_excel(r"data_supp\order filter.xlsx")
from datetime import date
df.loc[df['Store']=='Blibli','Warehouse Name']='Blibli Warehouse'
df.loc[df['Store'].isin(['Shopee', 'TikTok']),'Warehouse Name']='SSI Warehouse'

# %%
df1 = df[df['Store'].isin(['Lazada','Tokopedia','Nutrimart','Bukalapak']) & df['Warehouse Name'].isin(['Primary Warehouse']) & df['Year'].isin([2023]) & df['Month'].isin(['March','April','May'])]
df1 = df[]
# Out:
#                  Order # Sales Order ID              AWB  Paid Date  \
# 263709        1000111173            NaN                         NaN
# 263710        1000111174            NaN                         NaN
# 263711        1000111174            NaN                         NaN
# 263712        1000111174            NaN                         NaN
# 263713        1000111175            NaN   NTRM1000111175        NaN
# ...                  ...            ...              ...        ...
# 748353  1168097485193558   SO-132595728  JNAP-0168240184        NaN
# 748362  1168705263734248   SO-132611967  LXAD-2957050211        NaN
# 748364  1168705263734248   SO-132611967  LXAD-2957050211        NaN
# 748365  1168705263734248   SO-132611967  LXAD-2957050211        NaN
# 748366  1168705263734248   SO-132611967  LXAD-2957050211        NaN
#
#        Order Status           Order date  Week  Date  Month  Quarter  ...  \
# 263709     complete  2023-01-03 07:50:00   9.0   1.0  March      1.0  ...
# ...

# %%
#LSS

# %%
# import required module
import os
import time
import pandas as pd
import numpy as np
import math

# assign directory
directory = r"C:\Users\steven.nathanael\Downloads\1. Project Exe\1. Data Apr 23"
 
# iterate over files in
# that directory
SKU = pd.read_excel(r"C:\Users\steven.nathanael\OneDrive - PT Nutrifood Indonesia\List SKU LSS.xlsx")['Nama Produk'].unique()
LSS = pd.DataFrame(columns = ['Date','Product Name','Seller SKU','Visitors','Product Pageviews','Buyers','Orders','Units Sold'])
for filename in os.listdir(directory):
    g = os.path.join(directory, filename)
    
    i = filename.replace('Business Advisor - Product - Performance  (', '')
    i = i.replace(').xls', '')
    i = int(i)-1
    
    df = pd.read_excel(g ,converters = {'Seller SKU' : str}, skiprows=5)
    df = df[df['Product Name'].isin(SKU)]
    df1 = df[df['Seller SKU'].isin(['-'])].drop(columns = ['Seller SKU','SKU ID'])
    df2 = df[~df['Seller SKU'].isin(['-'])]
    df3 = pd.merge(df2[['Product Name','Product ID','Seller SKU']], df1[['Product Name','Product ID','Visitors','Buyers','Product Pageviews','Orders', 'Units Sold']], on = ['Product Name','Product ID'], how = 'left')
    df3 = df3[~df3['Visitors'].isnull()]
    df3['Year'] = 2023
    df3['Month'] = 'April'
    df3['Month_N'] = 4
    df3['Date'] = i
    
    LSS = LSS.append(df3)

    if os.path.isfile(g):
        print(g)

LSD = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\1. Project Exe\LIST SKU YANG LSS.xlsx")['Nama Produk'].unique()       
LSS['LSD'] = "No LSD"
LSS.loc[LSS['Product Name'].isin(LSD),'LSD']='LSD'

# %%
    with pd.ExcelWriter("LSS observation Apr 23.xlsx") as writer:  
        LSS.to_excel(writer, sheet_name="raw data",index=False)

# %%
# import required module
import os
import time
import pandas as pd
import numpy as np
import math

d = pd.read_excel(r"C:\Users\steven.nathanael\Downloads\Business Advisor - Product - Performance  (21).xls" ,converters = {'Seller SKU' : str}, skiprows = 5)
d1 = d[d['Seller SKU'].isin(['-'])].drop(columns = ['Seller SKU','SKU ID'])
d2 = d[~d['Seller SKU'].isin(['-'])]
d3 = pd.merge(d2[['Product Name','Product ID','Seller SKU']], d1[['Product Name','Product ID','Visitors','Buyers','Product Pageviews','Orders', 'Units Sold','Revenue']], on = ['Product Name','Product ID'], how = 'left')
d3 = d3[~d3['Visitors'].isnull()]

with pd.ExcelWriter("Item Laz January.xlsx") as writer:  
    d3.to_excel(writer, sheet_name="raw data",index=False)

# %%
# import required module
import os
import time
import pandas as pd
import numpy as np
import math
import xlrd

# assign directory
directory = r"C:\Users\steven.nathanael\Downloads\Analisis Hot Spot"
 
# iterate over files in
# that directory
SKU = pd.read_excel(r"C:\Users\steven.nathanael\OneDrive - PT Nutrifood Indonesia\List SKU Hotspot.xlsx")['Nama Produk'].unique()
LSS = pd.DataFrame(columns = ['Date','Product Name','Seller SKU','Visitors','Product Pageviews','Buyers','Orders','Units Sold'])
for filename in os.listdir(directory):
    g = os.path.join(directory, filename)
    
    date = filename[:6]
    i = filename[:2]
    j = date[-3:]

    df = pd.read_excel(g ,converters = {'Seller SKU' : str}, skiprows=5)
    df = df[df['Product Name'].isin(SKU)]
    df1 = df[df['Seller SKU'].isin(['-'])].drop(columns = ['Seller SKU','SKU ID'])
    df2 = df[~df['Seller SKU'].isin(['-'])]
    df3 = pd.merge(df2[['Product Name','Product ID','Seller SKU']], df1[['Product Name','Product ID','Visitors','Buyers','Product Pageviews','Orders', 'Units Sold']], on = ['Product Name','Product ID'], how = 'left')
    df3 = df3[~df3['Visitors'].isnull()]
    df3['Month'] = j
    df3['Month_N'] = 8
    df3.loc[df3['Month']=='Sep','Month_N']=9
    df3.loc[df3['Month']=='Jul','Month_N']=7
    df3['Date'] = int(i)
    
    LSS = LSS.append(df3)

    if os.path.isfile(g):
        print(g)

LSS
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_16360\2366486352.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   LSS = LSS.append(df3)
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_16360\2366486352.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   LSS = LSS.append(df3)
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_16360\2366486352.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   LSS = LSS.append(df3)
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_16360\2366486352.py:35: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   LSS = LSS.append(df3)
# ...

# %%
osf
# Out:
#                         order filter
# 0                        "Delivered"
# 1                  "Delivered, Open"
# 2   "Delivered, Open, Ready to Ship"
# 3               "Delivered, Printed"
# 4      "Delivered, Printed, Shipped"
# ..                               ...
# 62                  Sudah Settlement
# 63                         Completed
# 64                      Pesanan Tiba
# 65                           Selesai
# 66                      Pesanan Baru
#
# [67 rows x 1 columns]

# %%
#NEW RETURN SQUEEZED

# %%
md[md['Store Type'].isin(['Marketplace'])]['True datetime'].min()
# Out:
# Timestamp('2022-01-01 00:00:00')

# %%
df[df['Store'].isin(['Lazada']) & df['']]['Order Status'].unique)

# %%
#IMPORT STATUS
from datetime import date
osf=pd.read_excel(r"C:\Users\steven.nathanael\Documents\Python\Data\2. Master Data Git\data_supp\order filter.xlsx")

# %%
df1 = md[(md['Brand'].isin(['NS'])) &
         (md['Real SKU'].isin(['1N01402250', '(J)71110142'])) 
         & (md['Order Status'].isin(osf['order filter'].unique()))
         & (md['Store'].isin(['Lazada']))
        ]
print(df1['Real Nama Produk'].unique())
df1
# Out:
# ['NutriSari RTD Squeezed Orange 200 ml'
#  'Green Packing - 4 pack - NutriSari RTD Squeezed Orange 200 ml']
#                   Order # Sales Order ID              AWB  Paid Date  \
# 14511    1039969728133372   SO-128219478  LXAT-1003535686        NaN
# 68229    1048918955431523   SO-128510964  LXAT-1003619267        NaN
# 75565    1050686193857319   SO-128561763  LXAT-8001298641        NaN
# 89410    1044065846295402   SO-128626120  LXAT-8001317606        NaN
# 89411    1053257376117930   SO-128626115  LXAT-8001317248        NaN
# ...                   ...            ...              ...        ...
# 3332706  1028797378698307   SO-127863503              NaN        NaN
# 3345951  1030908319063050   SO-127938548              NaN        NaN
# 3355654  1023730646273981   SO-128002819              NaN        NaN
# 3356341  1023138434830784   SO-127981850              NaN        NaN
# 3356576  1031934301883362   SO-127974444              NaN        NaN
#
# ...

# %%
df1['True datetime'].min()
# Out:
# Timestamp('2022-11-18 07:07:00')

# %%
NR = df1.drop_duplicates('Order #')[['Order #','Year','Month','Date','Phone']].sort_values(by = ['Year', 'Month', 'Date'], ascending = True)
NR['cust_time'] = NR.groupby(['Phone']).cumcount()
NR['cust_type'] = NR['cust_time'].apply(lambda x: 'New' if (x == 0) else 'Return')

# %%
df_NR = pd.merge(df1,
                 NR[['Order #','cust_time','cust_type']], 
                 on ='Order #',
                 how = 'left')
df_NR
# Out:
#               Order # Sales Order ID              AWB  Paid Date Order Status  \
# 0    1039969728133372   SO-128219478  LXAT-1003535686        NaN    Completed
# 1    1048918955431523   SO-128510964  LXAT-1003619267        NaN    Completed
# 2    1050686193857319   SO-128561763  LXAT-8001298641        NaN    Completed
# 3    1044065846295402   SO-128626120  LXAT-8001317606        NaN    Completed
# 4    1053257376117930   SO-128626115  LXAT-8001317248        NaN    Completed
# ..                ...            ...              ...        ...          ...
# 398  1028797378698307   SO-127863503              NaN        NaN    Delivered
# 399  1030908319063050   SO-127938548              NaN        NaN    Delivered
# 400  1023730646273981   SO-128002819              NaN        NaN    Delivered
# 401  1023138434830784   SO-127981850              NaN        NaN    Delivered
# 402  1031934301883362   SO-127974444              NaN        NaN    Delivered
#
# ...

# %%
tes = df_NR.groupby(['Year','Month','Phone']).agg({'cust_time' : 'max'}).reset_index()
tes['cust_type'] = tes['cust_time'].apply(lambda x: 'New' if (x == 0) else 'Return')
tes
# Out:
#        Year      Month         Phone  cust_time cust_type
# 0    2022.0   December  081026089267          0       New
# 1    2022.0   December   08112644332          0       New
# 2    2022.0   December   08122106160          0       New
# 3    2022.0   December  081221705596          0       New
# 4    2022.0   December   08122266355          0       New
# ..      ...        ...           ...        ...       ...
# 355  2023.0  September  087889576338          1    Return
# 356  2023.0  September  088295182022          0       New
# 357  2023.0  September  088989201922          0       New
# 358  2023.0  September  089502393955          0       New
# 359  2023.0  September  089654964541          0       New
#
# [360 rows x 5 columns]

# %%
tes[['Year','Month']].drop_duplicates()
# Out:
#        Year      Month
# 0    2022.0   December
# 57   2022.0   November
# 69   2023.0      April
# 100  2023.0     August
# 143  2023.0   February
# 174  2023.0    January
# 194  2023.0       July
# 220  2023.0       June
# 239  2023.0      March
# 287  2023.0        May
# 308  2023.0    October
# 328  2023.0  September

# %%
    with pd.ExcelWriter("New Return Customer Squeezed Orange 23.xlsx") as writer:  
        tes.to_excel(writer, sheet_name="raw data",index=False)

# %%
#DATA TAHUN INI
import numpy as np
import pandas as pd
import xlwt
import datetime as dt
pd.options.mode.chained_assignment = None
import datetime
from datetime import date

#Read CSV
df = pd.read_csv(r"D:\Masterdata\Clean Data\data_all_15 November With Order Online.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

df['True datetime']=pd.to_datetime(df['True datetime'])
df['Real SKU']=df['Real SKU'].astype(str)
df['Phone']=df['Phone'].str.extract('(\d+)')

#IMPORT STATUS
from datetime import date
osf=pd.read_excel(r"C:\Users\steven.nathanael\Documents\Python\Data\2. Master Data Git\data_supp\order filter.xlsx")
df = df[df['Order Status'].isin(osf['order filter'].unique())]
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_24568\1990871461.py:11: DtypeWarning: Columns (12,15,20,24,25,27,29,30,31,32,33,34,35,36,37,39,53,54,57,59,60,66,67,73,74,80,81,87,88,94,95,101,102,108,122,123,134,135,136,153,159,161,167,168,169,172,173,174,175,176,180,181,183,196,197,198,199,200,201,202,203,205,209,210) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\Masterdata\Clean Data\data_all_15 November With Order Online.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

# %%
#PAYMENT DATA
df1 = df[df['Store'].isin(['Nutrimart']) &
         df['Brand'].isin(['NS','TS','HiLo','L-Men','WDANK']) &
         (df['True datetime'] >= '2023-01-01') &
         (df['True datetime'] < '2024-01-01')]
df2 = df1[['Order #','Year','Month','Date','Payment Channel','Brand','Sub Brand','Real Nama Produk','Total Net Before PPN','Qty. Invoiced']]
df2
# Out:
#             Order #    Year     Month  Date      Payment Channel  Brand  \
# 153      1000109585  2023.0   January   1.0  payment_subcription     TS
# 154      1000109586  2023.0   January   1.0  payment_subcription     TS
# 155      1000109587  2023.0   January   1.0                 free  L-Men
# 156      1000109588  2023.0   January   1.0  payment_subcription     TS
# 157      1000109589  2023.0   January   1.0                 free  L-Men
# ...             ...     ...       ...   ...                  ...    ...
# 2131973  1000118619  2023.0  December  31.0    snap_banktransfer     TS
# 2131975  1000118619  2023.0  December  31.0    snap_banktransfer     TS
# 2131977  1000118620  2023.0  December  31.0                 free  WDANK
# 2131978  1000118620  2023.0  December  31.0                 free     TS
# 2131980  1000118621  2023.0  December  31.0                 free  L-Men
#
#                 Sub Brand                      Real Nama Produk  \
# ...

# %%
    with pd.ExcelWriter("Payment Organik 2023.xlsx") as writer:  
        df2.to_excel(writer, sheet_name="raw data",index=False)

# %%
#CEK NS
df1 = df[df['Store'].isin(['Lazada']) &
         df['Brand'].isin(['Bundle']) &
         df['Real Nama Produk'].str.contains('Nutrisari', case = False, na = False) &
         df['Real Nama Produk'].str.contains('160|Blewah|Nipis', case = False, na = False)&
         (df['True datetime'] >= '2023-10-25') &
         (df['True datetime'] < '2023-11-01')]

# %%
df1.groupby(['Real Nama Produk']).agg({'Order #' : 'nunique'}).reset_index()
# Out:
#                             Real Nama Produk  Order #
# 0  NutriSari American Sweet Orange (160 Sch)       68
# 1                           NutriSari Blewah       62
# 2        NutriSari Florida Orange 160 sachet        7
# 3            NutriSari Jeruk Peras (160 Sch)      137
# 4            NutriSari Sweet Mango (160 Sch)       61
# 5             Nutrisari Jeruk Nipis 40's x 4       69

# %%
df2 = df1.groupby(['Phone','Real Nama Produk']).agg({'Order #' : 'nunique'}).reset_index()
df3 = df2.groupby(['Real Nama Produk']).agg({'Phone' : 'nunique'}).reset_index()
df2
# Out:
#             Phone                           Real Nama Produk  Order #
# 0      0811242435                           NutriSari Blewah        1
# 1      0811242435            NutriSari Sweet Mango (160 Sch)        1
# 2    081214128497  NutriSari American Sweet Orange (160 Sch)        2
# 3    081214128497            NutriSari Jeruk Peras (160 Sch)        1
# 4    081214128497             Nutrisari Jeruk Nipis 40's x 4        1
# ..            ...                                        ...      ...
# 285   08990631868             Nutrisari Jeruk Nipis 40's x 4        2
# 286   08991629505        NutriSari Florida Orange 160 sachet        1
# 287   08991629505            NutriSari Jeruk Peras (160 Sch)        2
# 288   08991629505            NutriSari Sweet Mango (160 Sch)        1
# 289   08995258862            NutriSari Jeruk Peras (160 Sch)        1
#
# [290 rows x 3 columns]

# %%
df4_1 = df1[df1['Real Nama Produk'].isin(['NutriSari Jeruk Peras (160 Sch)','NutriSari American Sweet Orange (160 Sch)'])]
df4 = df1[df1['Real Nama Produk'].isin(['NutriSari Jeruk Peras (160 Sch)','NutriSari American Sweet Orange (160 Sch)'])]['Order #'].unique()
df5 = df1[df1['Order #'].isin(df4) &
          df1['Real Nama Produk'].isin(['NutriSari Blewah','NutriSari Florida Orange 160 sachet','NutriSari Sweet Mango (160 Sch)',"Nutrisari Jeruk Nipis 40's x 4"])]

# %%
df5_1 = df1[(~df1['Order #'].isin(df4)) &
          df1['Real Nama Produk'].isin(['NutriSari Blewah','NutriSari Florida Orange 160 sachet','NutriSari Sweet Mango (160 Sch)',"Nutrisari Jeruk Nipis 40's x 4"])]

# %%
df1[df1['Order #'].isin(df4)][['Phone','Order #','Real Nama Produk','Qty. Invoiced']]
# Out:
#                 Phone           Order #  \
# 1691274  081288972316  1280013432793253
# 1691433  085173338399  1280001030104285
# 1691538  085173338399  1280027001312085
# 1691631   08990631868  1280002007078008
# 1691632   08990631868  1280002007078008
# ...               ...               ...
# 1751248  087714837085  1282334228695498
# 1758695  085747228127  1294111346140360
# 1762656  085781118380  1295373122181262
# 1763897  081388443708  1295047198315729
# 1764208  087888313422  1283615631525041
#
#                                   Real Nama Produk  Qty. Invoiced
# 1691274  NutriSari American Sweet Orange (160 Sch)            1.0
# 1691433  NutriSari American Sweet Orange (160 Sch)            1.0
# 1691538            NutriSari Jeruk Peras (160 Sch)            1.0
# 1691631  NutriSari American Sweet Orange (160 Sch)            2.0
# 1691632            NutriSari Sweet Mango (160 Sch)            2.0
# ...                                            ...            ...
# ...

# %%
df1[df1['Order #'].isin(df4)]['Real Nama Produk'].unique()
# Out:
# array(['NutriSari American Sweet Orange (160 Sch)',
#        'NutriSari Jeruk Peras (160 Sch)',
#        'NutriSari Sweet Mango (160 Sch)', 'NutriSari Blewah',
#        "Nutrisari Jeruk Nipis 40's x 4",
#        'NutriSari Florida Orange 160 sachet'], dtype=object)

# %%
print(len(df4_1['Phone'].unique()))
print(len(df4_1['Order #'].unique()))
# Out:
# 118
# 184

# %%
print(len(df5_1['Phone'].unique()))
print(len(df5_1['Order #'].unique()))
# Out:
# 95
# 154

# %%
df5
# Out:
#                   Order # Sales Order ID               AWB  Paid Date  \
# 1691632  1280002007078008   SO-137229173   JNAT-9003055188        NaN
# 1691633  1280002007078008   SO-137229173   JNAT-9003055188        NaN
# 1693153  1279799895947476   SO-137220123   LXAD-3152807914        NaN
# 1694782  1279623212898409   SO-137210667   LXAT-1007446008        NaN
# 1694785  1279623212898409   SO-137210667   LXAT-1007446008        NaN
# 1694940  1290934360338580   SO-137209545   LXAT-8005136993        NaN
# 1695003  1279570857238580   SO-137209143   JNAT-9003046459        NaN
# 1695005  1279570857238580   SO-137209143   JNAT-9003046459        NaN
# 1695054  1279559469578008   SO-137208897  NLIDAT9000061501        NaN
# 1695058  1279559469578008   SO-137208897  NLIDAT9000061501        NaN
# 1695768  1290863329178008   SO-137205465   LXAT-8005135130        NaN
# 1695771  1290863329178008   SO-137205465   LXAT-8005135130        NaN
# ...

# %%
len(df4_1['Order #'].unique())
# Out:
# 184

# %%
len(df6)
# Out:
# 184

# %%
df4_1['Real Nama Produk'].unique()
# Out:
# array(['NutriSari American Sweet Orange (160 Sch)',
#        'NutriSari Jeruk Peras (160 Sch)'], dtype=object)

# %%
df1_1 = df[df['Store'].isin(['Lazada']) &
         df['Brand'].isin(['Bundle']) &
         df['Real Nama Produk'].str.contains('Nutrisari', case = False, na = False) &
         df['Real Nama Produk'].str.contains('160|Blewah|Nipis', case = False, na = False)&
         (df['True datetime'] >= '2023-09-25') &
         (df['True datetime'] < '2023-10-01')]

# %%
df4_2 = df1_1[df1_1['Real Nama Produk'].isin(['NutriSari Jeruk Peras (160 Sch)','NutriSari American Sweet Orange (160 Sch)'])]

# %%
print(len(df4_2['Phone'].unique()))
print(len(df4_2['Order #'].unique()))
# Out:
# 364
# 624

# %%
#ANALISIS ITEM LAZADA

# %%
md1 = md[md['Store'].isin(['Lazada'])][['Order #','True datetime','Order Status','Year','Month','Date','Brand','Sub Brand','Real Nama Produk','Bundle Name','Total Net Before PPN','Qty. Invoiced','Phone','Customer Name']]

# %%
NR = md1.drop_duplicates('Order #')[['Order #','Year','Month','Date','True datetime','Phone']].sort_values(by = 'True datetime', ascending = True)
NR['cust_time'] = NR.groupby(['Phone']).cumcount()
NR['cust_type'] = NR['cust_time'].apply(lambda x: 'New' if (x == 0) else 'Return')

df_h2 = pd.merge(md1,
                 NR[['Order #','cust_time','cust_type']], 
                 on ='Order #',
                 how = 'left')
df_h2
# Out:
#                  Order #       True datetime Order Status    Year     Month  \
# 0       1037925735540886 2023-01-01 23:59:00    Completed  2023.0   January
# 1       1037921134200311 2023-01-01 23:51:00    Delivered  2023.0   January
# 2       1037918924816615 2023-01-01 23:43:00    Completed  2023.0   January
# 3       1037900176135508 2023-01-01 23:25:00    Delivered  2023.0   January
# 4       1028822221983326 2023-01-01 23:16:00    Cancelled  2023.0   January
# ...                  ...                 ...          ...     ...       ...
# 671851  1036500598596946 2022-12-31 09:50:00    Delivered  2022.0  December
# 671852  1036456794682702 2022-12-31 08:41:00    Delivered  2022.0  December
# 671853  1027904014391681 2022-12-31 21:39:00    Delivered  2022.0  December
# 671854  1036856917708649 2022-12-31 18:06:00    Delivered  2022.0  December
# 671855  1027457470613346 2022-12-31 10:10:00    Delivered  2022.0  December
#
#         Date   Brand         Sub Brand  \
# ...

# %%
    with pd.ExcelWriter("Lazada 22 23.xlsx") as writer:  
        df_h2.to_excel(writer, sheet_name="raw data",index=False)

# %%
#DATA HILO ECOM

#DATA TAHUN 2022
import numpy as np
import pandas as pd
import xlwt
import datetime as dt
pd.options.mode.chained_assignment = None
import datetime
from datetime import date

#Read CSV
df22 = pd.read_csv(r"D:\Masterdata\Data Tahunan\data_all_2022.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

df22['True datetime']=pd.to_datetime(df22['True datetime'])
df22['Real SKU']=df22['Real SKU'].astype(str)
df22['Phone']=df22['Phone'].str.extract('(\d+)')

df22 = df22[df22['Year'].isin([2022]) & df22['Brand'].isin(['HiLo']) & df22['Real SKU'].isin(['(E)2HF0112021','2HF0112021',
                                                                         '2HF0113021', '2101551195'
                                                                         '2101485195', '2101453195',
                                                                         '2101452195', '2101651195',
                                                                         '2101486195', '2101500195',
                                                                         '(E)2101469180','2101469180',
                                                                         '2HC0109021', '2HF0114021',
                                                                         '2101478180', '(E)2101478180',
                                                                         '2101609180', '2HC0112021',
                                                                         '2101710110', '(E)2101710110',
                                                                         '2101578180', '(E)2101578180',
                                                                         '2HC0113021'])]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#      10 from datetime import date
#      12 #Read CSV
# ---> 13 df22 = pd.read_csv(r"D:\Masterdata\Data Tahunan\data_all_2022.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})
#      15 df22['True datetime']=pd.to_datetime(df22['True datetime'])
#      16 df22['Real SKU']=df22['Real SKU'].astype(str)
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
#DATA TAHUN 2023
import numpy as np
import pandas as pd
import xlwt
import datetime as dt
pd.options.mode.chained_assignment = None
import datetime
from datetime import date

#Read CSV
df21 = pd.read_csv(r"D:\Masterdata\Clean Data\data_all_20 December With Order Online.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

df21['True datetime']=pd.to_datetime(df21['True datetime'])
df21['Real SKU']=df21['Real SKU'].astype(str)
df21['Phone']=df21['Phone'].str.extract('(\d+)')

df21 = df21[df21['Year'].isin([2023]) & df21['Brand'].isin(['HiLo']) & df21['Real SKU'].isin(['(E)2HF0112021','2HF0112021',
                                                                         '2HF0113021', '2101551195'
                                                                         '2101485195', '2101453195',
                                                                         '2101452195', '2101651195',
                                                                         '2101486195', '2101500195',
                                                                         '(E)2101469180','2101469180',
                                                                         '2HC0109021', '2HF0114021',
                                                                         '2101478180', '(E)2101478180',
                                                                         '2101609180', '2HC0112021',
                                                                         '2101710110', '(E)2101710110',
                                                                         '2101578180', '(E)2101578180',
                                                                         '2HC0113021'])]
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_13392\4036585446.py:11: DtypeWarning: Columns (15,24,25,27,29,30,31,32,33,34,35,36,37,39,53,54,57,59,60,66,67,73,74,80,81,87,88,94,95,101,102,108,122,123,134,135,136,153,159,161,167,168,169,172,173,174,175,176,180,181,183,196,197,198,199,200,201,202,203,205,209,210) have mixed types. Specify dtype option on import or set low_memory=False.
#   df21 = pd.read_csv(r"D:\Masterdata\Clean Data\data_all_20 December With Order Online.csv", sep = ';',converters = {'Phone' : str, 'Order #' : str, 'AWB' : str})

# %%
df = pd.concat([df22, df21], ignore_index = True)

# %%
df['Real Nama Produk'].unique()
# Out:
# array(['HiLo School Chocolate 1000 gr', 'HiLo Active Chocolate 1000 gr',
#        'HiLo Gold Plain 1000 gr', 'HiLo Teen Chocolate 1000 gr',
#        'HiLo Teen Taro 500gr', 'HiLo Joint Plus Orange 140 gram',
#        'HiLo Active Caramel Latte 500g',
#        'HiLo Gold Sweet Potato 500 gram', 'HiLo Multigrain Original 500g',
#        'HiLo School Vanilla 1000g',
#        '(Near ED) HiLo Joint Plus Orange 140 gram',
#        'Near ED - HiLo Gold Sweet Potato 500 gram',
#        'HiLo School 3+ Soya Vanilla Malt 400g',
#        'HiLo School 3+ Strawberry Pop 400g', 'HiLo School Original 400g',
#        '(Near ED) HiLo Active Caramel Latte 500g',
#        'HiLo Teen Original 400g',
#        '(Near ED) HiLo Multigrain Original 500g',
#        'HiLo Teen+ Berries Club 400g',
#        'Near ED - HiLo School 3+ Soya Vanilla Malt 400g',
#        'HiLo Teen HiProtein Melon 400g'], dtype=object)

# %%
osf=pd.read_excel(r"data_supp\order filter.xlsx")
df1 = df[df['Store Type'].isin(['Marketplace','Organik']) & df['Order Status'].isin(osf['order filter'].unique())]
df1
# Out:
#                  Order # Sales Order ID                AWB  \
# 0         220101KFCCK211  #SO-115793058      JT84671297710
# 3         220101KFHEV9U2  #SO-115793402       JP5963390883
# 4         220101KFJ6K6V1  #SO-115793539       JP4944858628
# 5         220101KFJFMJYX  #SO-115793953       JP2046393260
# 6         220101KFNS2YJ2  #SO-115794027       JP3227511039
# ...                  ...            ...                ...
# 193996  1318720434202745   SO-138447644    LXAT-1008680193
# 193997  1318663454245457   SO-138446508    LXAT-1008678357
# 193998       12144303684   SO-138444286   BLI2611239480464
# 193999    231209PK5YJ37B   SO-138444233  SPXID03023556879C
# 194001    231208M98297QY   SO-138423989  SPXID03687730000C
#
#                   Paid Date Order Status           Order date  Week  Date  \
# 0       2022-01-01 00:03:00    Delivered  2022-01-01 00:02:00  52.0   1.0
# 3       2022-01-01 00:05:00    Delivered  2022-01-01 00:05:00  52.0   1.0
# ...

# %%
df1 = df1.groupby(['Year','Month','Date','Store','Sub Brand','Real SKU','Real Nama Produk']).agg({'Total Net Before PPN' : 'sum', 'Qty. Invoiced' : 'sum'}).reset_index()
df1
# Out:
#          Year      Month  Date      Store    Sub Brand    Real SKU  \
# 0      2022.0      April   1.0     Blibli  HILO ACTIVE  2101452195
# 1      2022.0      April   1.0     Blibli    HILO GOLD  2101500195
# 2      2022.0      April   1.0     Blibli    HILO GOLD  2101710110
# 3      2022.0      April   1.0     Blibli  HILO SCHOOL  2101453195
# 4      2022.0      April   1.0     Blibli    HILO TEEN  2101651195
# ...       ...        ...   ...        ...          ...         ...
# 27753  2023.0  September  30.0  Tokopedia  HILO SCHOOL  2101486195
# 27754  2023.0  September  30.0  Tokopedia  HILO SCHOOL  2HF0112021
# 27755  2023.0  September  30.0  Tokopedia  HILO SCHOOL  2HF0114021
# 27756  2023.0  September  30.0  Tokopedia    HILO TEEN  2101609180
# 27757  2023.0  September  30.0  Tokopedia    HILO TEEN  2101651195
#
#                             Real Nama Produk  Total Net Before PPN  \
# 0              HiLo Active Chocolate 1000 gr              105000.0
# ...

# %%
    with pd.ExcelWriter("hilo exclusive ecom.xlsx") as writer:  
        df1.to_excel(writer, sheet_name="raw data",index=False)

# %%
df['Store'].unique()
# Out:
# array(['Blibli', 'Nutrimart', 'Tokopedia', 'Shopee', 'Lazada', 'TikTok',
#        'JD Indonesia', 'Bukalapak', 'Aladin Mall', 'Order Online',
#        'Orami Shopping', 'MITRA TOKOPEDIA', 'Shopee Sell-In',
#        'ECOM RETAIL - TANIHUB', 'ECOM RETAIL - JD ID', 'WARUNG PINTAR',
#        'ECOM RETAIL - EMOS', 'ECOM RETAIL - SAYUR BOX JAKARTA',
#        'CHILIBELI', 'ALGOLAB SOLUTION', 'CARI SAYUR',
#        'ECOM RETAIL - BAYI NINJA JAKARTA',
#        'ECOM RETAIL - INDOPASIFIK FARMA MEDIKA INDONESIA',
#        'ECOM RETAIL - SAYUR BOX SURABAYA', 'ECOM RETAIL - ASTRO',
#        'ECOM RETAIL - TOKO NOW', 'ECOM RETAIL - JOYBOX(COSMART)',
#        'ECOM RETAIL - FRESHBOX', 'ECOM RETAIL - HAKUNA MATATA PELAUT',
#        'ECOM RETAIL - SEGARI', 'ECOM RETAIL - COMMON GROUND',
#        'ECOM RETAIL - DINKES SURABAYA', 'ECOM RETAIL - TRUFFLE BELLY'],
#       dtype=object)

# %%
df1 = df[df['Brand'].isin(['TS']) & df['Store Type'].isin(['Marketplace','Organic']) 
         & (~df['Store'].isin(['Order Online'])) & df['Month'].isin(['October','November','December'])]
df2 = df[df['Brand'].isin(['HiLo']) & df['Sub Brand'].isin(['HILO ACTIVE','HILO GOLD']) & df['Store Type'].isin(['Marketplace','Organic']) 
         & (~df['Store'].isin(['Order Online'])) & df['Month'].isin(['October','November','December'])]

# %%
df3 = df1.append(df2, ignore_index = True)
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_24800\1482218919.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df1.append(df2, ignore_index = True)

# %%
df4 = df3.groupby(['Order #']).agg({'Total' : 'sum'}).reset_index()
df4 = df4[df4['Total'] >= 100000]
order = df4['Order #'].unique()

# %%
osf=pd.read_excel(r"data_supp\order filter.xlsx")
df5 = df3[df3['Order #'].isin(order) & df['Order Status'].isin(osf['order filter'].unique())]
df5
# Out:
# C:\Users\steven.nathanael\AppData\Local\Temp\ipykernel_24800\3843837863.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df5 = df3[df3['Order #'].isin(order) & df['Order Status'].isin(osf['order filter'].unique())]
#                             Order # Sales Order ID                AWB  \
# 1                        1000116668            NaN   0125432300075970
# 2                        1000116668            NaN   0125432300075970
# 3                        1000116668            NaN   0125432300075970
# 4                        1000116668            NaN   0125432300075970
# 5                        1000116668            NaN   0125432300075970
# ...                             ...            ...                ...
# 210310  INV/20231229/MPL/3650621563   SO-139167464  TKGTL-0000053KPM5
# 210311             1336017666420383   SO-139166937
# 210314  INV/20231229/MPL/3650398043   SO-139163918  TKGTL-0000053JF1H
# ...

# %%
df6 = pd.pivot_table(df5, values = 'Order #', index = 'Store', columns = 'Month', aggfunc = 'nunique', fill_value = 0)
df6['S3M'] = (df6['December'] + df6['November'] + df6['October'])/3
df6['sum'] = df6['S3M'].sum()
df6['Kontribusi'] = df6['S3M']/df6['sum']*100
df6
# Out:
# Month        December  November  October          S3M           sum  \
# Store
# Aladin Mall         4         0        2     2.000000  18896.333333
# Blibli            367       423      366   385.333333  18896.333333
# Bukalapak          20        21       33    24.666667  18896.333333
# Lazada           2915      3082     3078  3025.000000  18896.333333
# Nutrimart         106       115      109   110.000000  18896.333333
# Shopee           8905     10024     9512  9480.333333  18896.333333
# TikTok            975         0      458   477.666667  18896.333333
# Tokopedia        5553      5095     5526  5391.333333  18896.333333
#
# Month        Kontribusi
# Store
# Aladin Mall    0.010584
# Blibli         2.039196
# Bukalapak      0.130537
# Lazada        16.008397
# Nutrimart      0.582124
# Shopee        50.170227
# TikTok         2.527827
# Tokopedia     28.531108

# %%
df22['Brand'].unique()
# Out:
# array(['HiLo', 'L-Men', 'TS', 'Bundle', 'NS', 'Gimmick', 'WDANK',
#        'Bonus Produk', 'WRP', 'Heavenly Blush', 'Lain Lain', 'L-MEN'],
#       dtype=object)

# %%
df22[df22['Brand'].isin(['L-MEN'])]['Store'].unique()
# Out:
# array(['ECOM RETAIL - BAYI NINJA JAKARTA', 'ECOM RETAIL - JD ID',
#        'ECOM RETAIL - SAYUR BOX SURABAYA', 'ECOM RETAIL - ASTRO'],
#       dtype=object)

# %%
df22_pure = df22.copy()
osf=pd.read_excel(r"data_supp\order filter.xlsx")
df22 = df22[df22['Store'].isin(['Lazada']) & df22['Order Status'].isin(osf['order filter'].unique())]
df22
# Out:
#                   Order # Sales Order ID               AWB  \
# 7470      764433245299618  #SO-115847218   LXAD-2462355428
# 7471      764433245299618  #SO-115847218   LXAD-2462355428
# 7483      770840313437690  #SO-115847267  NLIDAP1341321592
# 7495      764431462770437  #SO-115847338   LXAT-0017435972
# 7497      764437445511088  #SO-115847449   LXAD-2462355432
# ...                   ...            ...               ...
# 1898910  1036500598596946   SO-128106859   LXAT-1003479485
# 1898933  1036456794682702   SO-128105554   LXAD-2789707484
# 1898989  1027904014391681   SO-128119233   LXAD-2789737693
# 1898991  1036856917708649   SO-128116158   LXAT-1003483515
# 1899001  1027457470613346   SO-128107215   LXAT-1003479578
#
#                    Paid Date Order Status           Order date  Week  Date  \
# 7470     2022-02-01 12:02:00    Delivered  2022-02-01 12:02:00  52.0   2.0
# 7471     2022-02-01 12:02:00    Delivered  2022-02-01 12:02:00  52.0   2.0
# ...

# %%
df22_lite = df22[['Order #', 'Month','Brand', 'Real SKU', 'Real Nama Produk', 'Bundle Name', 'Qty. Invoiced']]
df22_lite
# Out:
#                   Order #     Month   Brand      Real SKU  \
# 7470      764433245299618   January  Bundle    2101461P24
# 7471      764433245299618   January    HiLo       2101461
# 7483      770840313437690   January      TS    2104110110
# 7495      764431462770437   January      TS    2104115163
# 7497      764437445511088   January  Bundle  2104115163P3
# ...                   ...       ...     ...           ...
# 1898910  1036500598596946  December      TS    2104390210
# 1898933  1036456794682702  December      TS    2104394210
# 1898989  1027904014391681  December      TS    2104543105
# 1898991  1036856917708649  December      TS    2104543105
# 1899001  1027457470613346  December      TS    2104543105
#
#                                           Real Nama Produk  \
# 7470      Hilo Teen Chocolate Ready To Drink Susu [24 pcs]
# 7471                            HiLo Teen RTD Coklat 200ml
# 7483       Tropicana Slim Sweet Orange Sugar Free 10sachet
# ...

# %%
df22_lite.to_excel(r'data 2022.xlsx', index = False)
#df22[(df22['True datetime'] >= '2022-07-01')].to_csv(r'data 2022 part2.csv', sep = ';', index = False)

# %%
#MODERN PER KOTA 2023

# %%
osf=pd.read_excel(r"data_supp\order filter.xlsx")

# %%
df1 = df[(~df['Exported Parent Item'].str.contains(' PLS ', case = False, na = False))&
         (df['Order Status'].isin(osf['order filter'].unique())) &
         (df['Brand'].isin(['NS','TS','HiLo','L-Men','WDANK']))]

# %%
mappingarea=pd.read_excel("data_supp\Database Area untuk Report.xlsx")
mappingarea=mappingarea.rename(columns=({'Region':'Real Region',"City":'Region Group'}))
# temp=data_all.merge(mappingarea,how='left')
# temp.loc[temp['Region Group'].isnull(),'Real Region']='Retail Online'
for i in mappingarea['Real Region'].unique():
    print(i)
    reg=mappingarea[mappingarea['Real Region']==i]['Region Group'].unique()
    df1.loc[df1['Region Group'].isin(reg),'Real Region']=i
df1.loc[df1['Region Group'].isnull(),'Real Region']='Retail Online'
# Out:
# Sumatera 1
# BARA
# Sumatera 2
# Jabodetabek
# Jawa Tengah
# Kalimantan
# Sulawesi
# Jawa Timur
# Jawa Barat
# PUMA

# %%
df1['Exported Parent Item'].unique()
# Out:
# array(['L-MEN PLATINUM CHOCO LATTE 6KLRX800G',
#        'L-MEN ADV CAPPUCINO 12DX250G',
#        'L-MEN RTD HI PROTEIN 2GO CHOCO 24PX200ML',
#        'L-MEN PROTEINMIX COFFEE 12SBX6SX33G',
#        'L-MEN DAILY CHOCOLATE 12DX250G', 'L-MEN GM CHOCOLATE 6DX500G',
#        'L-MEN LW MANGO STICKY RICE 6DX12SX25G',
#        'L-MEN LW CHOCOLATE CEREAL 6DX12SX25G',
#        'L-MEN LOSE WEIGHT AVOCADO COFFEE 6DX12SX25G',
#        'L-MEN DAILY POPCORN CARAMEL 12DX250G',
#        'L-MEN PLATINUM VANILLA CARAMEL 6KLRX800G',
#        'L-MEN GAINMASS KLEPON LATTE 6DX500G', 'L-MEN GM BANANA 12DX225G',
#        'L-MEN GM CHOCOLATE 12DX225G',
#        'L-MEN PLATINUM CHOCO LATTE REF 6DX800G',
#        'L-MEN BAR CRUNCHY CHOCOLATE 6SBX12SX22G',
#        'L-MEN GAINMASS TARO 6DX500G', 'L-MEN ADV CHOCO VANILLA 6DX500G',
#        'L-MEN PLANTPROTEIN OGURA 6Dx216G', 'L-MEN GM TARO 12DX225G',
#        'L-MEN PROTEIN CRUNCH BBQ BEEF 20BX20G',
# ...

# %%
marks1 = df['Exported Parent Item'].unique()
marks2 = df1['Exported Parent Item'].unique()

marks1,marks2 = [i for i in marks1 if i not in marks2],[j for j in marks2 if j not in marks1]

# %%
for i in df1.columns :
    print(i)
# Out:
# Order #
# Sales Order ID
# AWB
# Paid Date
# Order Status
# Order date
# Week
# Date
# Month
# Quarter
# Year
# Channel
# SKU
# Brand
# Product Name
# Bundle Name
# Price List NFI
# Qty. Invoiced
# Total Net
# Sub Brand
# Real SKU
# Real Nama Produk
# Parent Item
# Parent SKU
# Bundle Flag
# Customer Email
# Customer Name
# Customer Group
# Phone
# Country
# Region
# City
# Kecamatan
# Kelurahan
# Address
# Zip Code
# Shipping Name
# Shipping Courier
# Total
# Coupon Code
# Qty. Ordered
# Qty. Shipped
# Qty. Refunded
# Item Price
# Subtotal
# Discounts
# Tax
# Total incl. Tax
# Invoiced
# Tax Invoiced
# Invoiced incl. Tax
# Refunded
# Refunded incl. Tax
# Cart Name Rule
# Payment Channel
# Voucher Amount
# Discount Poin Reward
# Ship Date
# Discount Product
# Produk 1
# SKU Produk 1
# PCS Produk 1
# Price List NFI 1
# Subtotal Produk 1
# Harga Display 1
# Harga Cost 1
# Produk 2
# SKU Produk 2
# PCS Produk 2
# Price List NFI 2
# Subtotal Produk 2
# Harga Display 2
# Harga Cost 2
# ...

# %%
df2 = df1[['Order #','Date','Month','Year','Store Type','Store','Brand','Sub Brand','Real SKU','Real Nama Produk','Exported Parent Item','Qty. Invoiced','Total Net Before PPN','City','Real Region']]
df2['City'].replace('Kab.','Kabupaten', regex=True, inplace = True)
df2
# Out:
#                               Order #  Date     Month    Year     Store Type  \
# 2                         12121396731   1.0   January  2023.0    Marketplace
# 4                         12121385635   1.0   January  2023.0    Marketplace
# 6                         12121413238   2.0   January  2023.0    Marketplace
# 7                         12121409053   2.0   January  2023.0    Marketplace
# 8                         12121385758   1.0   January  2023.0    Marketplace
# ...                               ...   ...       ...     ...            ...
# 2260968  Nubi -ECOM RETAIL - TOKO NOW   8.0  December  2023.0  Retail Online
# 2260969      Nubi -ECOM RETAIL - EMOS   7.0  December  2023.0  Retail Online
# 2260970      Nubi -ECOM RETAIL - EMOS   7.0  December  2023.0  Retail Online
# 2260971      Nubi -ECOM RETAIL - EMOS   7.0  December  2023.0  Retail Online
# 2260972      Nubi -ECOM RETAIL - EMOS   7.0  December  2023.0  Retail Online
#
# ...

# %%
df3 = df2.groupby(['Month','Store Type','Store','Brand','Sub Brand','Real Region','City']).agg({'Qty. Invoiced' : 'sum', 'Total Net Before PPN' : 'sum'}).reset_index()
df3
# Out:
#            Month   Store Type        Store  Brand    Sub Brand  Real Region  \
# 0          April  Marketplace  Aladin Mall   HiLo     HILO RTD  Jawa Tengah
# 1          April  Marketplace  Aladin Mall   HiLo  HILO SCHOOL  Jawa Tengah
# 2          April  Marketplace  Aladin Mall     NS       NS RTD  Jawa Tengah
# 3          April  Marketplace       Blibli   HiLo  HILO ACTIVE  Jabodetabek
# 4          April  Marketplace       Blibli   HiLo  HILO ACTIVE  Jabodetabek
# ...          ...          ...          ...    ...          ...          ...
# 67285  September      Organic    Nutrimart     TS     TS MERAH  Jawa Tengah
# 67286  September      Organic    Nutrimart     TS     TS MERAH  Jawa Tengah
# 67287  September      Organic    Nutrimart     TS     TS MERAH   Jawa Timur
# 67288  September      Organic    Nutrimart     TS     TS MERAH   Sumatera 1
# 67289  September      Organic    Nutrimart  WDANK        WDANK   Jawa Barat
#
# ...

# %%
df3.to_excel(r'data modern 2023.xlsx', index = False)

# %%
#Cek No HP

# %%
md = md[(md['Order Status'].isin(osf['order filter'].unique()))]

# %%
md[md['Store'].isin(['JD Indonesia'])]['True datetime'].max()
# Out:
# Timestamp('2023-02-02 21:57:00')

# %%
hp_jd = md[md['Store'].isin(['JD Indonesia'])][['Store','Phone','Customer Name']].drop_duplicates()
hp_jd['backphone'] = hp_jd['Phone'].str[-4:]
hp_jd['frontname'] = hp_jd['Customer Name'].str[:4].str.lower()
hp_jd['ucode'] = hp_jd['frontname'] +'_' + hp_jd['backphone']
hp_jd
# Out:
#                 Store         Phone      Customer Name backphone frontname  \
# 2589     JD Indonesia  081317755911   Jondistira Volta      5911      jond
# 4254     JD Indonesia  081286688080  Takwa sekti imara      8080      takw
# 7266     JD Indonesia    0811892728       KOPERASI NGK      2728      kope
# 7403     JD Indonesia  081381065005               idar      5005      idar
# 7551     JD Indonesia   08161813595     martin chandra      3595      mart
# ...               ...           ...                ...       ...       ...
# 4072199  JD Indonesia   08567426689   Fendhy Wicaksono      6689      fend
# 4073530  JD Indonesia  085864401124          Mira mira      1124      mira
# 4073821  JD Indonesia  085311480275              Anita      0275      anit
# 4075554  JD Indonesia  089670499894               arni      9894      arni
# 4077117  JD Indonesia  081231309007      rendra gofood      9007      rend
#
#              ucode
# 2589     jond_5911
# 4254     takw_8080
# ...

# %%
hp_tokopedia = md[md['Store'].isin(['Tokopedia']) & (md['True datetime'] >= '2023-02-03')][['Store','Phone','Customer Name']].drop_duplicates()
hp_tokopedia['frontname'] = hp_tokopedia['Customer Name'].str[:4].str.lower()
hp_tokopedia['ucode'] = hp_tokopedia['frontname'] +'_' + hp_tokopedia['Phone']
hp_tokopedia
# Out:
#              Store Phone          Customer Name frontname      ucode
# 163065   Tokopedia  0619         Erieka agustin      erie  erie_0619
# 163075   Tokopedia  4475      Fuad Ibnu Suyuthi      fuad  fuad_4475
# 163092   Tokopedia  1250      Stevi mega arista      stev  stev_1250
# 163093   Tokopedia  1047       Robby Hermansyah      robb  robb_1047
# 163120   Tokopedia  4000            Samuel Aryo      samu  samu_4000
# ...            ...   ...                    ...       ...        ...
# 2177306  Tokopedia  6713               rentu dn      rent  rent_6713
# 2177308  Tokopedia  2345                   Ofan      ofan  ofan_2345
# 2177326  Tokopedia  0609         Rangga Wirawan      rang  rang_0609
# 2177490  Tokopedia  1444                  Jonto      jont  jont_1444
# 2177497  Tokopedia  2252  Risha, sebelah warung      rish  rish_2252
#
# [112020 rows x 5 columns]

# %%
hp_lazada = md[md['Store'].isin(['Lazada']) & (md['True datetime'] >= '2023-02-03')][['Store','Phone']].drop_duplicates()
hp_bli = md[md['Store'].isin(['Blibli']) & (md['True datetime'] >= '2023-02-03')][['Store','Phone']].drop_duplicates()

# %%
    with pd.ExcelWriter("Phone.xlsx") as writer:  
        hp_jd.to_excel(writer, sheet_name="jd",index=False)
        hp_tokopedia.to_excel(writer, sheet_name="tok",index=False)
        hp_lazada.to_excel(writer, sheet_name="laz",index=False)
        hp_bli.to_excel(writer, sheet_name="bli",index=False)

# %%
md['Store'].unique()
# Out:
# array(['Blibli', 'Nutrimart', 'Tokopedia', 'Shopee', 'Lazada', 'TikTok',
#        'JD Indonesia', 'Bukalapak', 'Aladin Mall', 'Order Online',
#        'Orami Shopping', 'ECOM RETAIL - EMOS',
#        'ECOM RETAIL - SAYUR BOX JAKARTA', 'ECOM RETAIL - ASTRO',
#        'ECOM RETAIL - TOKO NOW', 'ECOM RETAIL - JOYBOX(COSMART)',
#        'ECOM RETAIL - INDOPASIFIK FARMA MEDIKA INDONESIA',
#        'ECOM RETAIL - FRESHBOX', 'ECOM RETAIL - HAKUNA MATATA PELAUT',
#        'ECOM RETAIL - SEGARI', 'ECOM RETAIL - COMMON GROUND',
#        'ECOM RETAIL - DINKES SURABAYA', 'ECOM RETAIL - TRUFFLE BELLY',
#        'ECOM RETAIL - BAYI NINJA JAKARTA', 'ECOM RETAIL - TANIHUB',
#        'ECOM RETAIL - JD ID', 'ECOM RETAIL - SAYUR BOX SURABAYA'],
#       dtype=object)

# %%
hp_2022 =  md[md['Store Type'].isin(['Marketplace','Organic']) &(~md['Store'].isin(['Tokopedia','Shopee','TikTok','Order Online'])) & (md['Year'].isin([2022]))][['Store','Phone','Customer Name']].drop_duplicates()
hp_2023 =  md[md['Store Type'].isin(['Marketplace','Organic']) &(~md['Store'].isin(['Tokopedia','Shopee','TikTok','Order Online'])) & (md['Year'].isin([2023]))][['Store','Phone','Customer Name']].drop_duplicates()

# %%
hp_tok22 = md[md['Store'].isin(['Tokopedia']) & (md['Year'].isin([2022]))][['Store','Phone','Customer Name']].drop_duplicates()
hp_tok22['frontname'] = hp_tok22['Customer Name'].str[:4].str.lower()
hp_tok22['ucode'] = hp_tok22['frontname'] +'_' + hp_tok22['Phone']
hp_tok22
# Out:
#              Store         Phone     Customer Name frontname  \
# 2180327  Tokopedia  081514717958     Alex Nurcahyo      alex
# 2180349  Tokopedia   08129925732          verawaty      vera
# 2180414  Tokopedia  085157245526             FANIA      fani
# 2180451  Tokopedia  085726171516   noviana permata      novi
# 2180459  Tokopedia  089606093505     Liana Novyana      lian
# ...            ...           ...               ...       ...
# 4077583  Tokopedia          8817             Sassa      sass
# 4077598  Tokopedia          5315             sodri      sodr
# 4077601  Tokopedia          0263  Putu Budi Artana      putu
# 4077647  Tokopedia          0302            Nico s      nico
# 4077680  Tokopedia          6809         Novi Linx      novi
#
#                      ucode
# 2180327  alex_081514717958
# 2180349   vera_08129925732
# 2180414  fani_085157245526
# 2180451  novi_085726171516
# 2180459  lian_089606093505
# ...                    ...
# 4077583          sass_8817
# ...

# %%
hp_tok23 = md[md['Store'].isin(['Tokopedia']) & (md['Year'].isin([2023]))][['Store','Phone','Customer Name']].drop_duplicates()
hp_tok23['frontname'] = hp_tok23['Customer Name'].str[:4].str.lower()
hp_tok23['ucode'] = hp_tok23['frontname'] +'_' + hp_tok23['Phone']
hp_tok23
# Out:
#              Store Phone          Customer Name frontname      ucode
# 430      Tokopedia  7110          Endro Suwanto      endr  endr_7110
# 431      Tokopedia  4967           M. Naipospos      m. n  m. n_4967
# 432      Tokopedia  8025        wiharja sunarjo      wiha  wiha_8025
# 449      Tokopedia  1314                 Olivia      oliv  oliv_1314
# 450      Tokopedia  5358                   Tira      tira  tira_5358
# ...            ...   ...                    ...       ...        ...
# 2177306  Tokopedia  6713               rentu dn      rent  rent_6713
# 2177308  Tokopedia  2345                   Ofan      ofan  ofan_2345
# 2177326  Tokopedia  0609         Rangga Wirawan      rang  rang_0609
# 2177490  Tokopedia  1444                  Jonto      jont  jont_1444
# 2177497  Tokopedia  2252  Risha, sebelah warung      rish  rish_2252
#
# [124461 rows x 5 columns]

# %%
    with pd.ExcelWriter("Phone.xlsx") as writer:  
        hp_2022.to_excel(writer, sheet_name="22",index=False)
        hp_2023.to_excel(writer, sheet_name="23",index=False)
        hp_tok22.to_excel(writer, sheet_name="tok 22",index=False)
        hp_tok23.to_excel(writer, sheet_name="tok 23",index=False)
